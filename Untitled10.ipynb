# %%
import numpy as np
import pandas as pd

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop1.csv")
hotels_detail.head()
# Out:
#    item_id                title          LOCATION  \
# 0        1     HUNZA VIEW HOTEL  KARIM ABAD HUNZA
# 1        2  HOTEL HUNZA EMBASSY  KARIM ABAD HUNZA
# 2        3         DARBAR HOTEL  KARIM ABAD HUNZA
# 3        4           HAIDER INN     ALIABAD HUNZA
# 4        5     HUNZA SERENA INN  KARIM ABAD HUNZA
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES   CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
hotels_detail.shape
# Out:
# (722, 8)

# %%
g =hotels_detail.groupby("CITY")
g

# %%
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
# Out:
# city: ASTORE
#
#
# data:      item_id                          title                   LOCATION  \
# 566      567         HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567      568                   KAMRAN HOTEL           RAMA ROAD ASTORE
# 568      569              KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582      583        RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583      584        GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# 608      609                 MIR RESTAURANT                     SKARDU
# 618      619         HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 619      620                   KAMRAN HOTEL           RAMA ROAD ASTORE
# 620      621              KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 621      622          RAMA GREEN VIEW HOTEL           RAMA ROAD ASTORE
# 634      635        RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 694      695   KHADIN RESORT AND VIEW POINT                     SKARDU
# 695      696          ASTORE INN RESTAURANT      NEAR DC OFFICE ASTORE
# 696      697                  TASBEEL HOTEL  ASTORE VALLEY ROAD ASTORE
# 697      698              TASBEL RESTAURANT  ASTORE VALLEY ROAD ASTORE
# 698      699                    BULAN HOTEL           LINK ROAD ASTORE
# 699      700               BULAN RESTAURANT           LINK ROAD ASTORE
# 700      701                 RAMA INN HOTEL           LINK ROAD ASTORE
# 701      702            RAMA INN RESTAUTANT           LINK ROAD ASTORE
# 702      703       NEW DIWAN BROTHERS HOTEL  ASTORE VALLEY ROAD ASTORE
# 703      704  NEW DIWAN BROTHERS RESTAUARNT  ASTORE VALLEY ROAD ASTORE
# 704      705                 AL-IMRAN HOTEL  ASTORE VALLEY ROAD ASTORE
# 705      706            AL-IMRAN RESTAURANT  ASTORE VALLEY ROAD ASTORE
# 706      707                  RABBANI HOTEL  ASTORE VALLEY ROAD ASTORE
# 707      708  WAZIR GUEST HIUSE RAMA ASTORE           MAIN RAMA ASTORE
# 708      709        RAMA MIDWAY GUEST HOSUE                     ASTORE
# 709      710                   KAMRAN HOTEL                     ASTORE
# 710      711              WAZIR MEHEL HOTEL             GORIKOT ASTORE
# 711      712          WAZIR MEHEL RESTURANT             GORIKOT ASTORE
# 712      713                PTDC MOTEL RAMA                     ASTORE
# 713      714                 PARADISE HOTEL                     ASTORE
# 714      715            PARADISE RESTAURANT                     ASTORE
# 715      716            MOUNTAIN FOOD POINT       EDIGAH ASOTRE GILGIT
# 716      717    BAB RAMA GUEST HOUSE ASTORE                     ASTORE
# 717      718        KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 718      719      NANGA PARBAT HOTEL ASTORE                     ASTORE
# 719      720          KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 720      721                   PATHAN HOTEL                     ASTORE
# 721      722                    THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                              ROOM TYPE  \
# 566  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 608  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 618  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 619  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 620  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 621  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 634  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 694  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 695  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 696  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 697  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 698  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 699  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 700  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 701  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 702  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 703  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 704  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 705  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 706  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 707  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 708  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 709  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 710  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 711  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 712  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 713  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 714  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 715  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 716  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 717  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 718  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 719  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 720  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 721  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES    CITY    PARKING  \
# 566  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 608  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 618  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 619  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 620  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 621  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 634  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 694  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 695  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 696  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 697  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 698  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 699  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 700  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 701  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 702  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 703  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 704  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 705  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 706  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 707  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 708  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 709  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 710  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 711  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 712  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 713  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 714  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 715  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 716  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 717  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 718  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 719  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 720  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 721  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                REVIEWS
# 566  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 608  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 618  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 619  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 620  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 621  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 634  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 694  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 695  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 696  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 697  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 698  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 699  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 700  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 701  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 702  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 703  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 704  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 705  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 706  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 707  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 708  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 709  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 710  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 711  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 712  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 713  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 714  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 715  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 716  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 717  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 718  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 719  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 720  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 721  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# city: GILGIT
# data:      item_id                  title                   LOCATION  \
# 338      339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339      340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340      341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341      342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342      343             PARK HOTEL        AIRPORT ROAD GILGIT
# ..       ...                    ...                        ...
# 561      562     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 562      563  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 563      564         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 564      565   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 565      566        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                              ROOM TYPE  \
# 338  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ..                                                 ...
# 561  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 562  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 563  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 564  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 565  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES    CITY    PARKING  \
# 338  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ..                             ...     ...        ...
# 561  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 562  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 563  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 564  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 565  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                REVIEWS
# 338  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ..                                                 ...
# 561  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 562  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 563  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 564  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 565  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [228 rows x 8 columns]
# city: HUNZA
#
#
# data:      item_id                title           LOCATION  \
# 0          1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1          2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2          3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3          4           HAIDER INN      ALIABAD HUNZA
# 4          5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ..       ...                  ...                ...
# 333      334   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 334      335   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 335      336           WHITE ROCK  SHISKAT GOJAL HUN
# 336      337    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 337      338        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                              ROOM TYPE  \
# 0    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ..                                                 ...
# 333  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 334  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 335  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 336  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 337  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES   CITY    PARKING  \
# 0    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ..                             ...    ...        ...
# 333  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 334  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 335  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 336  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 337  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                REVIEWS
# 0    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ..                                                 ...
# 333  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 334  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 335  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 336  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 337  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [338 rows x 8 columns]
# city: SKARDU
#
#
# data:      item_id                       title             LOCATION  \
# 569      570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570      571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571      572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572      573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573      574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ..       ...                         ...                  ...
# 689      690  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 690      691              CITY INN HOTEL               SKARDU
# 691      692                BELLA VISTA                SKARDU
# 692      693             PUNAR INN HOTEL               SKARDU
# 693      694      ADVENTURE GHAZI RESORT               SKARDU
#
#                                              ROOM TYPE  \
# 569  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ..                                                 ...
# 689  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 690  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 691  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 692  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 693  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES    CITY    PARKING  \
# 569  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ..                             ...     ...        ...
# 689  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 690  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 691  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 692  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 693  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                REVIEWS
# 569  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ..                                                 ...
# 689  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 690  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 691  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 692  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 693  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [117 rows x 8 columns]

# %%
g.get_group('HUNZA')
# Out:
#      item_id                title           LOCATION  \
# 0          1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1          2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2          3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3          4           HAIDER INN      ALIABAD HUNZA
# 4          5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ..       ...                  ...                ...
# 333      334   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 334      335   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 335      336           WHITE ROCK  SHISKAT GOJAL HUN
# 336      337    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 337      338        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                              ROOM TYPE  \
# 0    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4    TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ..                                                 ...
# 333  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 334  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 335  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 336  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 337  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES   CITY    PARKING  \
# 0    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4    HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ..                             ...    ...        ...
# 333  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 334  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 335  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 336  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 337  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                REVIEWS
# 0    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4    EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ..                                                 ...
# 333  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 334  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 335  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 336  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 337  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [338 rows x 8 columns]

# %%
g.get_group('ASTORE')
# Out:
#      item_id                          title                   LOCATION  \
# 566      567         HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567      568                   KAMRAN HOTEL           RAMA ROAD ASTORE
# 568      569              KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582      583        RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583      584        GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# 608      609                 MIR RESTAURANT                     SKARDU
# 618      619         HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 619      620                   KAMRAN HOTEL           RAMA ROAD ASTORE
# 620      621              KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 621      622          RAMA GREEN VIEW HOTEL           RAMA ROAD ASTORE
# 634      635        RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 694      695   KHADIN RESORT AND VIEW POINT                     SKARDU
# 695      696          ASTORE INN RESTAURANT      NEAR DC OFFICE ASTORE
# 696      697                  TASBEEL HOTEL  ASTORE VALLEY ROAD ASTORE
# 697      698              TASBEL RESTAURANT  ASTORE VALLEY ROAD ASTORE
# 698      699                    BULAN HOTEL           LINK ROAD ASTORE
# 699      700               BULAN RESTAURANT           LINK ROAD ASTORE
# 700      701                 RAMA INN HOTEL           LINK ROAD ASTORE
# 701      702            RAMA INN RESTAUTANT           LINK ROAD ASTORE
# 702      703       NEW DIWAN BROTHERS HOTEL  ASTORE VALLEY ROAD ASTORE
# 703      704  NEW DIWAN BROTHERS RESTAUARNT  ASTORE VALLEY ROAD ASTORE
# 704      705                 AL-IMRAN HOTEL  ASTORE VALLEY ROAD ASTORE
# 705      706            AL-IMRAN RESTAURANT  ASTORE VALLEY ROAD ASTORE
# 706      707                  RABBANI HOTEL  ASTORE VALLEY ROAD ASTORE
# 707      708  WAZIR GUEST HIUSE RAMA ASTORE           MAIN RAMA ASTORE
# 708      709        RAMA MIDWAY GUEST HOSUE                     ASTORE
# 709      710                   KAMRAN HOTEL                     ASTORE
# 710      711              WAZIR MEHEL HOTEL             GORIKOT ASTORE
# 711      712          WAZIR MEHEL RESTURANT             GORIKOT ASTORE
# 712      713                PTDC MOTEL RAMA                     ASTORE
# 713      714                 PARADISE HOTEL                     ASTORE
# 714      715            PARADISE RESTAURANT                     ASTORE
# 715      716            MOUNTAIN FOOD POINT       EDIGAH ASOTRE GILGIT
# 716      717    BAB RAMA GUEST HOUSE ASTORE                     ASTORE
# 717      718        KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 718      719      NANGA PARBAT HOTEL ASTORE                     ASTORE
# 719      720          KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 720      721                   PATHAN HOTEL                     ASTORE
# 721      722                    THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                              ROOM TYPE  \
# 566  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 608  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 618  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 619  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 620  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 621  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 634  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 694  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 695  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 696  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 697  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 698  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 699  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 700  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 701  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 702  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 703  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 704  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 705  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 706  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 707  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 708  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 709  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 710  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 711  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 712  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 713  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 714  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 715  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 716  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 717  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 718  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 719  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 720  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 721  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES    CITY    PARKING  \
# 566  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 608  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 618  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 619  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 620  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 621  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 634  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 694  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 695  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 696  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 697  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 698  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 699  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 700  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 701  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 702  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 703  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 704  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 705  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 706  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 707  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 708  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 709  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 710  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 711  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 712  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 713  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 714  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 715  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 716  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 717  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 718  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 719  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 720  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 721  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                REVIEWS
# 566  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 608  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 618  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 619  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 620  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 621  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 634  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 694  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 695  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 696  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 697  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 698  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 699  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 700  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 701  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 702  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 703  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 704  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 705  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 706  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 707  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 708  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 709  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 710  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 711  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 712  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 713  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 714  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 715  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 716  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 717  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 718  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 719  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 720  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 721  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
g.get_group('GILGIT')
# Out:
#      item_id                  title                   LOCATION  \
# 338      339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339      340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340      341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341      342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342      343             PARK HOTEL        AIRPORT ROAD GILGIT
# ..       ...                    ...                        ...
# 561      562     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 562      563  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 563      564         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 564      565   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 565      566        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                              ROOM TYPE  \
# 338  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ..                                                 ...
# 561  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 562  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 563  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 564  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 565  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES    CITY    PARKING  \
# 338  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ..                             ...     ...        ...
# 561  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 562  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 563  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 564  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 565  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                REVIEWS
# 338  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ..                                                 ...
# 561  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 562  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 563  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 564  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 565  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [228 rows x 8 columns]

# %%
g.get_group('SKARDU')
# Out:
#      item_id                       title             LOCATION  \
# 569      570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570      571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571      572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572      573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573      574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ..       ...                         ...                  ...
# 689      690  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 690      691              CITY INN HOTEL               SKARDU
# 691      692                BELLA VISTA                SKARDU
# 692      693             PUNAR INN HOTEL               SKARDU
# 693      694      ADVENTURE GHAZI RESORT               SKARDU
#
#                                              ROOM TYPE  \
# 569  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ..                                                 ...
# 689  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 690  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 691  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 692  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 693  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                    NEAR FACILITIES    CITY    PARKING  \
# 569  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ..                             ...     ...        ...
# 689  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 690  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 691  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 692  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 693  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                REVIEWS
# 569  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ..                                                 ...
# 689  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 690  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 691  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 692  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 693  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [117 rows x 8 columns]

# %%
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list1.csv")
hotels_list.head(15)
# Out:
#     item_id ROOM/NIGHT  STANDRED  NO OF ROOMS  BUDGET  DAYS
# 0         1      10000      2300           18  50,000     3
# 1         2      10000      3500           20  50,000     4
# 2         3      19000      5000           15  50,000     2
# 3         4      12000      4500           10  50,000     7
# 4         5      13000      3500           28  50,000     6
# 5         6      12000      3000           15  50,000     5
# 6         7      10000      4000           15  50,000     4
# 7         8      13000      9000           15  50,000     4
# 8         9      11000      7000           17  50,000     3
# 9        10      12000      4300           13  50,000     4
# 10       11      13000      3400           12  50,000     5
# 11       12       9000      8500           12  50,000     3
# 12       13       5000      1000           10  50,000     4
# 13       14      20000      3500           20  50,000     7
# 14       15      11000      3000           11  40,000     3

# %%
hotels_list.shape
# Out:
# (723, 6)

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df.head(5)
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp       title             LOCATION  \
# 0      278      603       5  891295330  SKARDU INN  COLLOGE ROAD SKARDU
# 1      128      603       5  879966839  SKARDU INN  COLLOGE ROAD SKARDU
# 2       42      603       4  881107502  SKARDU INN  COLLOGE ROAD SKARDU
# 3       90      603       5  891385132  SKARDU INN  COLLOGE ROAD SKARDU
# 4       44      603       4  878347420  SKARDU INN  COLLOGE ROAD SKARDU
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
df1.head()
# Out:
#    user_id  item_id  rating  timestamp       title       LOCATION  \
# 0        0       50       5  881250949  ALAM LODGE  ALIABAD HUNZA
# 1      290       50       5  880473582  ALAM LODGE  ALIABAD HUNZA
# 2       79       50       4  891271545  ALAM LODGE  ALIABAD HUNZA
# 3        2       50       5  888552084  ALAM LODGE  ALIABAD HUNZA
# 4        8       50       5  879362124  ALAM LODGE  ALIABAD HUNZA
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES   CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
# Out:
#    user_id  item_id  rating  timestamp                      title LOCATION  \
# 0      160      719       3  876857977  NANGA PARBAT HOTEL ASTORE   ASTORE
# 1      276      719       3  877935336  NANGA PARBAT HOTEL ASTORE   ASTORE
# 2      246      719       4  884924026  NANGA PARBAT HOTEL ASTORE   ASTORE
# 3      405      719       1  885547447  NANGA PARBAT HOTEL ASTORE   ASTORE
# 4      222      719       1  881060578  NANGA PARBAT HOTEL ASTORE   ASTORE
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
# Out:
#    user_id  item_id  rating  timestamp              title  \
# 0       22      377       1  878887116  PALACE RESTAURANT
# 1        5      377       1  878844615  PALACE RESTAURANT
# 2      314      377       3  877890982  PALACE RESTAURANT
# 3       13      377       1  882399219  PALACE RESTAURANT
# 4      222      377       1  881060205  PALACE RESTAURANT
#
#                LOCATION                                          ROOM TYPE  \
# 0  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# SKARDU INN               4.123853
# FIVE STAR GUEST HOUSE    4.105263
# HAMALIYA HOTEL SKARDU    4.102273
# HARGISA HUT              4.100000
# FIVE STAR RESTAURANT     4.086420
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# SKARDU INN             436
# HOTEL HARGISA          284
# SKARDU VILAS           262
# SEHRISH GUEST HOUSE    256
# GREEN GUEST HOUSE      219
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())

ratings.head()
# Out:
#                                rating
# title
# ADVENTURE GHAZI RESORT       4.045455
# AL-YOSUF BANQUET             4.038674
# ASTORE INN HOTEL             3.658537
# BALTISTAN CONTINENTAL HOTEL  3.426829
# BALTISTAN MOUNTAIN CHALET    2.949153

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                                rating  num of ratings
# title
# ADVENTURE GHAZI RESORT       4.045455              44
# AL-YOSUF BANQUET             4.038674             181
# ASTORE INN HOTEL             3.658537              41
# BALTISTAN CONTINENTAL HOTEL  3.426829              82
# BALTISTAN MOUNTAIN CHALET    2.949153             118

# %%
ratings.head()
# Out:
#                                rating  num of ratings
# title
# ADVENTURE GHAZI RESORT       4.045455              44
# AL-YOSUF BANQUET             4.038674             181
# ASTORE INN HOTEL             3.658537              41
# BALTISTAN CONTINENTAL HOTEL  3.426829              82
# BALTISTAN MOUNTAIN CHALET    2.949153             118

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
hotelmat = df.pivot_table(index='user_id',columns='title',values='rating')
hotelmat.head()
# Out:
# title    ADVENTURE GHAZI RESORT  AL-YOSUF BANQUET  ASTORE INN HOTEL  \
# user_id
# 7                           NaN               4.0               5.0
# 8                           NaN               NaN               NaN
# 9                           NaN               NaN               NaN
# 10                          5.0               NaN               4.0
# 11                          NaN               5.0               NaN
#
# title    BALTISTAN CONTINENTAL HOTEL  BALTISTAN MOUNTAIN CHALET  \
# user_id
# 7                                3.0                        2.5
# 8                                NaN                        NaN
# 9                                NaN                        NaN
# 10                               NaN                        4.0
# 11                               3.0                        3.0
#
# title    BALTISTAN VILLAGE GUEST HOUSE  BALTISTAN VILLAGE RESTAURANT  \
# user_id
# 7                                  1.0                           5.0
# 8                                  NaN                           NaN
# 9                                  NaN                           NaN
# 10                                 NaN                           NaN
# 11                                 NaN                           NaN
#
# title    BELLA VISTA   CANDELA RESORT  CAPRAFAL GUEST HOUSE  ...  \
# user_id                                                      ...
# 7                 NaN             NaN                   5.0  ...
# 8                 NaN             3.0                   NaN  ...
# 9                 NaN             NaN                   NaN  ...
# 10                4.0             4.0                   4.0  ...
# 11                4.0             NaN                   NaN  ...
#
# title    SKARDU RESTAURANT  SKARDU VIEW POINT AND HUTS  \
# user_id
# 7                      4.0                         2.0
# 8                      NaN                         NaN
# 9                      NaN                         NaN
# 10                     5.0                         NaN
# 11                     3.0                         NaN
#
# title    SKARDU VIEW POINT HOTEL  SKARDU VILAS  SNOWLAND GUEST HOUSE  \
# user_id
# 7                            5.0           4.0                   5.0
# 8                            NaN           NaN                   NaN
# 9                            NaN           NaN                   NaN
# 10                           NaN           NaN                   NaN
# 11                           NaN           NaN                   NaN
#
# title    SNOWLAND PALACE SKARDU  SUMMIT RESTAURANT  TAJ MAHAL HOTEL  \
# user_id
# 7                           3.5                3.5              4.0
# 8                           NaN                NaN              NaN
# 9                           NaN                NaN              NaN
# 10                          3.0                NaN              NaN
# 11                          4.0                NaN              NaN
#
# title    TIBET HOTEL SHANGRILA SKARDU  YAK TAIL RESORT
# user_id
# 7                                 4.0              NaN
# 8                                 NaN              1.0
# 9                                 NaN              NaN
# 10                                NaN              NaN
# 11                                NaN              NaN
#
# [5 rows x 81 columns]

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                         rating  num of ratings
# title
# SKARDU INN            4.123853             436
# HOTEL HARGISA         3.570423             284
# SKARDU VILAS          3.339695             262
# SEHRISH GUEST HOUSE   3.199219             256
# GREEN GUEST HOUSE     2.808219             219
# SKARDU RESTAURANT     4.025381             197
# INDUS MOTEL           3.603093             194
# CAPRAFAL GUEST HOUSE  3.619792             192
# SARFARANGI HOTEL      3.587912             182
# AL-YOSUF BANQUET      4.038674             181

# %%
ratings.head()
# Out:
#                                rating  num of ratings
# title
# ADVENTURE GHAZI RESORT       4.045455              44
# AL-YOSUF BANQUET             4.038674             181
# ASTORE INN HOTEL             3.658537              41
# BALTISTAN CONTINENTAL HOTEL  3.426829              82
# BALTISTAN MOUNTAIN CHALET    2.949153             118

# %%
star_user_ratings = hotelmat['SKARDU INN']
standard_user_ratings = hotelmat['SKARDU RESTAURANT']
star_user_ratings.head()
# Out:
# user_id
# 7     4.5
# 8     NaN
# 9     NaN
# 10    5.0
# 11    4.0
# Name: SKARDU INN, dtype: float64

# %%
similar_to_star = hotelmat.corrwith(star_user_ratings)
similar_to_standard = hotelmat.corrwith(standard_user_ratings)
# Out:
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_star = pd.DataFrame(similar_to_star,columns=['Correlation'])
corr_star.dropna(inplace=True)
corr_star.head()
# Out:
#                              Correlation
# title
# ADVENTURE GHAZI RESORT          0.198915
# AL-YOSUF BANQUET                0.163934
# ASTORE INN HOTEL                0.375959
# BALTISTAN CONTINENTAL HOTEL     0.172324
# BALTISTAN MOUNTAIN CHALET       0.085255

# %%
corr_star.sort_values('Correlation',ascending=False).head(10)
# Out:
#                               Correlation
# title
# TIBET HOTEL SHANGRILA SKARDU     1.000000
# SKARDU INN                       1.000000
# CITY INN HOTEL                   1.000000
# SHALIMAR HOTEL SKARDU            0.563932
# INDUS VIEW HOTEL                 0.446930
# HOTEL MASHABRUM                  0.415654
# HOTEL SARFARANGA RESTAURANT      0.408248
# FIVE STAR RESTAURANT             0.396929
# MIR HOTEL                        0.392204
# SKARDU RESTAURANT                0.384180

# %%
corr_star = corr_star.join(ratings['num of ratings'])
corr_star.head()
# Out:
#                              Correlation  num of ratings
# title
# ADVENTURE GHAZI RESORT          0.198915              44
# AL-YOSUF BANQUET                0.163934             181
# ASTORE INN HOTEL                0.375959              41
# BALTISTAN CONTINENTAL HOTEL     0.172324              82
# BALTISTAN MOUNTAIN CHALET       0.085255             118

# %%
corr_star[corr_star['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                             Correlation  num of ratings
# title
# SKARDU INN                     1.000000             436
# INDUS VIEW HOTEL               0.446930             115
# FIVE STAR RESTAURANT           0.396929             162
# SKARDU RESTAURANT              0.384180             197
# HILTON INTERNATIONAL HOTEL     0.343287             169

# %%
corr_standard = pd.DataFrame(similar_to_standard,columns=['Correlation'])
corr_standard.dropna(inplace=True)
corr_standard = corr_standard.join(ratings['num of ratings'])
corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                 Correlation  num of ratings
# title
# SKARDU RESTAURANT                  1.000000             197
# GHAZI HOTEL LAKE UPPER KACHURA     0.628735             125
# HOTEL RIVER VIEW SHIGER            0.590969             107
# CONTINENTAL GUEST HOUSE SKARDU     0.453238             116
# HOTEL HIMALAYA SKARDU              0.392761             138

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df1.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# GOLDEN PEAK GUEST HOUSE    4.500000
# MINGLING GUEST HOUSE       4.466443
# HCC GUEST HOUSE            4.466102
# SHAH QULI INN HOTEL        4.447761
# SECOND HOME HOTEL          4.445230
# Name: rating, dtype: float64

# %%
df1.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# ALAM LODGE                  584
# HIDDEN VALLEY LAKE HOTEL    509
# SILK WAY GUEST HOUSE        508
# DUMANI RESTAURANT           507
# GHALAPAN GUEST HOUSE        485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df1.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                         rating
# title
# AIR LAND HOTEL        3.781818
# AL -BARKAT HOTEL      3.896321
# AL MADINA HOTEL       4.206522
# AL MADINA RESTAURANT  3.876923
# AL QAIM GUEST HOUSE   3.622222

# %%
ratings['num of ratings'] = pd.DataFrame(df1.groupby('title')['rating'].count())
ratings.head()
# Out:
#                         rating  num of ratings
# title
# AIR LAND HOTEL        3.781818             220
# AL -BARKAT HOTEL      3.896321             299
# AL MADINA HOTEL       4.206522             368
# AL MADINA RESTAURANT  3.876923              65
# AL QAIM GUEST HOUSE   3.622222              45

# %%
ratings.head()
# Out:
#                         rating  num of ratings
# title
# AIR LAND HOTEL        3.781818             220
# AL -BARKAT HOTEL      3.896321             299
# AL MADINA HOTEL       4.206522             368
# AL MADINA RESTAURANT  3.876923              65
# AL QAIM GUEST HOUSE   3.622222              45

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df1.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    AIR LAND HOTEL  AL -BARKAT HOTEL  AL MADINA HOTEL  \
# user_id
# 0                   NaN               NaN              5.0
# 1                   3.0               5.0              5.0
# 2                   NaN               NaN              NaN
# 3                   NaN               NaN              NaN
# 4                   NaN               NaN              NaN
#
# title    AL MADINA RESTAURANT  AL QAIM GUEST HOUSE  AL-HAMIYA RESTAURANT  \
# user_id
# 0                         NaN                  NaN                   NaN
# 1                         5.0                  4.0                   5.0
# 2                         NaN                  NaN                   NaN
# 3                         NaN                  NaN                   NaN
# 4                         NaN                  NaN                   NaN
#
# title    AL-HIMALIYA HOTEL  AL-JANNAT HOTEL  AL-MEHMOOD HOTEL  \
# user_id
# 0                      NaN              NaN               NaN
# 1                      NaN              5.0               5.0
# 2                      3.0              NaN               NaN
# 3                      NaN              NaN               NaN
# 4                      NaN              NaN               NaN
#
# title    AL-MEHMOOD RESTAURANT  ...  VALLEY FOOD RESTAURANT  VANTAGE RSORT  \
# user_id                         ...
# 0                          NaN  ...                     NaN            NaN
# 1                          3.0  ...                     3.0            3.0
# 2                          NaN  ...                     NaN            NaN
# 3                          NaN  ...                     NaN            NaN
# 4                          NaN  ...                     NaN            NaN
#
# title    VILLAGE GUEST HOUSE  VISTA HOTEL  WHITE APPRICOT LODGE  WHITE ROCK  \
# user_id
# 0                        NaN          NaN                   NaN         NaN
# 1                        4.0          4.0                   4.0         NaN
# 2                        NaN          NaN                   NaN         NaN
# 3                        NaN          NaN                   NaN         1.0
# 4                        NaN          NaN                   NaN         NaN
#
# title    WOLF SHADOW HOTEL  WORLD ROOF HOTEL  YAK GRILL RESTAURANT  \
# user_id
# 0                      NaN               NaN                   NaN
# 1                      2.0               2.0                   NaN
# 2                      NaN               NaN                   3.0
# 3                      NaN               NaN                   NaN
# 4                      NaN               4.0                   NaN
#
# title    ZIA GUEST HOUSE
# user_id
# 0                    NaN
# 1                    4.0
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 335 columns]

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                             rating  num of ratings
# title
# ALAM LODGE                4.359589             584
# HIDDEN VALLEY LAKE HOTEL  3.803536             509
# SILK WAY GUEST HOUSE      4.155512             508
# DUMANI RESTAURANT         4.007890             507
# GHALAPAN GUEST HOUSE      3.156701             485
# SOST GUEST HOUSE          3.656965             481
# ATTABAD LAKE VIEW HOTEL   3.441423             478
# HUNZA VIEW HOTEL          3.878319             452
# BABAGONDI HOTEL           3.631090             431
# CPEC GUEST HOUSE          3.438228             429

# %%
ratings.head()
# Out:
#                         rating  num of ratings
# title
# AIR LAND HOTEL        3.781818             220
# AL -BARKAT HOTEL      3.896321             299
# AL MADINA HOTEL       4.206522             368
# AL MADINA RESTAURANT  3.876923              65
# AL QAIM GUEST HOUSE   3.622222              45

# %%
starwars_user_ratings = moviemat['MANSERA HOTEL']
liarliar_user_ratings = moviemat['AL -BARKAT HOTEL']
starwars_user_ratings.head()
# Out:
# user_id
# 0    NaN
# 1    4.0
# 2    NaN
# 3    NaN
# 4    NaN
# Name: MANSERA HOTEL, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                       Correlation
# title
# AIR LAND HOTEL           0.158871
# AL -BARKAT HOTEL         0.074354
# AL MADINA HOTEL          0.191770
# AL MADINA RESTAURANT     0.318058
# AL QAIM GUEST HOUSE      0.661475

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                Correlation
# title
# MANSERA HOTEL                     1.000000
# MULBERY LODGE                     0.943042
# MIDWAY HOTEL ASTAK                0.942809
# ARMANI FAST POINT                 0.927173
# REHMAN GUEST HOUSE                0.750555
# AL QAIM GUEST HOUSE               0.661475
# MARGOS INN                        0.566864
# PEARLS HUTS RESORT                0.551227
# GOLDEN PEAK GUEST HOUSE           0.522233
# HUNZA GATEWAY HOTEL NASIRABAD     0.510164

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                       Correlation  num of ratings
# title
# AIR LAND HOTEL           0.158871             220
# AL -BARKAT HOTEL         0.074354             299
# AL MADINA HOTEL          0.191770             368
# AL MADINA RESTAURANT     0.318058              65
# AL QAIM GUEST HOUSE      0.661475              45

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                        Correlation  num of ratings
# title
# MANSERA HOTEL             1.000000             326
# RAKAPOSHI GUEST HOUSE     0.414266             127
# BALTIT CAF�               0.379952             110
# GARELTH INN HOTEL         0.323330             114
# BED AND BREAD             0.316300             256

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                    Correlation  num of ratings
# title
# AL -BARKAT HOTEL      1.000000             299
# MOSHKA RESORT         0.617763             114
# DUMANI HOTEL          0.444979             221
# SIFAT GUEST HOUSE     0.386112             102
# AL-MEHMOOD HOTEL      0.380693             187

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df2.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# WAZIR MEHEL HOTEL          4.000000
# RAMA INN HOTEL             4.000000
# AL-IMRAN HOTEL             3.992701
# RABBANI HOTEL              3.928571
# KARACHII BIRYANI CENTRE    3.687500
# Name: rating, dtype: float64

# %%
df2.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# KAMRAN HOTEL                     352
# RAMA MIDWAY GUEST HOSUE          164
# AL-IMRAN HOTEL                   137
# BULAN HOTEL                      102
# WAZIR GUEST HIUSE RAMA ASTORE    101
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df2.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                                rating
# title
# AL-IMRAN HOTEL               3.992701
# AL-IMRAN RESTAURANT          2.666667
# ASTORE INN RESTAURANT        3.139241
# BAB RAMA GUEST HOUSE ASTORE  2.817073
# BULAN HOTEL                  3.676471

# %%
ratings['num of ratings'] = pd.DataFrame(df2.groupby('title')['rating'].count())
ratings.head()
# Out:
#                                rating  num of ratings
# title
# AL-IMRAN HOTEL               3.992701             137
# AL-IMRAN RESTAURANT          2.666667               6
# ASTORE INN RESTAURANT        3.139241              79
# BAB RAMA GUEST HOUSE ASTORE  2.817073              82
# BULAN HOTEL                  3.676471             102

# %%
ratings.head()
# Out:
#                                rating  num of ratings
# title
# AL-IMRAN HOTEL               3.992701             137
# AL-IMRAN RESTAURANT          2.666667               6
# ASTORE INN RESTAURANT        3.139241              79
# BAB RAMA GUEST HOUSE ASTORE  2.817073              82
# BULAN HOTEL                  3.676471             102

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df2.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    AL-IMRAN HOTEL  AL-IMRAN RESTAURANT  ASTORE INN RESTAURANT  \
# user_id
# 7                   NaN                  NaN                    NaN
# 8                   NaN                  NaN                    NaN
# 10                  4.0                  4.0                    4.0
# 11                  NaN                  NaN                    NaN
# 12                  NaN                  NaN                    NaN
#
# title    BAB RAMA GUEST HOUSE ASTORE  BULAN HOTEL  BULAN RESTAURANT  \
# user_id
# 7                                NaN          NaN               NaN
# 8                                NaN          NaN               NaN
# 10                               NaN          4.0               4.0
# 11                               2.0          4.0               NaN
# 12                               NaN          NaN               NaN
#
# title    GRACE LAND HOTEL SKARDU  HOTEL MOUNTAIN LOGOON   KAMRAN HOTEL  \
# user_id
# 7                            4.0                     2.0           4.5
# 8                            NaN                     NaN           4.0
# 10                           NaN                     NaN           4.0
# 11                           NaN                     NaN           2.0
# 12                           NaN                     NaN           NaN
#
# title    KAMRAN RESTAURANT  ...  RAMA GREEN VIEW HOTEL  RAMA INN HOTEL  \
# user_id                     ...
# 7                      4.5  ...                    4.0             NaN
# 8                      NaN  ...                    NaN             NaN
# 10                     NaN  ...                    NaN             4.0
# 11                     NaN  ...                    NaN             NaN
# 12                     NaN  ...                    NaN             NaN
#
# title    RAMA INN RESTAUTANT  RAMA MIDWAY GUEST HOSUE  TASBEEL HOTEL  \
# user_id
# 7                        NaN                      2.5            NaN
# 8                        NaN                      NaN            NaN
# 10                       3.0                      4.0            3.0
# 11                       NaN                      NaN            NaN
# 12                       NaN                      NaN            NaN
#
# title    TASBEL RESTAURANT  THE KITCHEN  WAZIR GUEST HIUSE RAMA ASTORE  \
# user_id
# 7                      NaN          NaN                            NaN
# 8                      NaN          NaN                            NaN
# 10                     4.0          NaN                            4.0
# 11                     NaN          3.0                            NaN
# 12                     NaN          NaN                            3.0
#
# title    WAZIR MEHEL HOTEL  WAZIR MEHEL RESTURANT
# user_id
# 7                      NaN                    NaN
# 8                      NaN                    NaN
# 10                     4.0                    4.0
# 11                     NaN                    NaN
# 12                     NaN                    NaN
#
# [5 rows x 33 columns]

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                  rating  num of ratings
# title
# KAMRAN HOTEL                   3.562500             352
# RAMA MIDWAY GUEST HOSUE        3.615854             164
# AL-IMRAN HOTEL                 3.992701             137
# BULAN HOTEL                    3.676471             102
# WAZIR GUEST HIUSE RAMA ASTORE  3.475248             101
# HOTEL MOUNTAIN LOGOON          3.040404              99
# PARADISE RESTAURANT            3.275862              87
# KARACHI NIHARI CENTRE          3.023256              86
# BAB RAMA GUEST HOUSE ASTORE    2.817073              82
# ASTORE INN RESTAURANT          3.139241              79

# %%
ratings.head()
# Out:
#                                rating  num of ratings
# title
# AL-IMRAN HOTEL               3.992701             137
# AL-IMRAN RESTAURANT          2.666667               6
# ASTORE INN RESTAURANT        3.139241              79
# BAB RAMA GUEST HOUSE ASTORE  2.817073              82
# BULAN HOTEL                  3.676471             102

# %%
starwars_user_ratings = moviemat['RAMA MIDWAY GUEST HOSUE']
liarliar_user_ratings = moviemat['KAMRAN HOTEL']
starwars_user_ratings.head()
# Out:
# user_id
# 7     2.5
# 8     NaN
# 10    4.0
# 11    NaN
# 12    NaN
# Name: RAMA MIDWAY GUEST HOSUE, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                              Correlation
# title
# AL-IMRAN HOTEL                  0.012190
# AL-IMRAN RESTAURANT             0.774597
# ASTORE INN RESTAURANT           0.110302
# BAB RAMA GUEST HOUSE ASTORE    -0.411347
# BULAN HOTEL                     0.349667

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                Correlation
# title
# RAMA MIDWAY GUEST HOSUE           1.000000
# RAMA INN HOTEL                    0.845154
# PARADISE HOTEL                    0.813871
# KHADIN RESORT AND VIEW POINT      0.789352
# AL-IMRAN RESTAURANT               0.774597
# BULAN RESTAURANT                  0.728139
# THE KITCHEN                       0.536728
# MOUNTAIN FOOD POINT               0.483234
# WAZIR GUEST HIUSE RAMA ASTORE     0.478913
# RAMA GREEN VIEW HOTEL             0.463050

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                              Correlation  num of ratings
# title
# AL-IMRAN HOTEL                  0.012190             137
# AL-IMRAN RESTAURANT             0.774597               6
# ASTORE INN RESTAURANT           0.110302              79
# BAB RAMA GUEST HOUSE ASTORE    -0.411347              82
# BULAN HOTEL                     0.349667             102

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                Correlation  num of ratings
# title
# RAMA MIDWAY GUEST HOSUE           1.000000             164
# WAZIR GUEST HIUSE RAMA ASTORE     0.478913             101
# BULAN HOTEL                       0.349667             102
# KAMRAN HOTEL                      0.030592             352
# AL-IMRAN HOTEL                    0.012190             137

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                Correlation  num of ratings
# title
# KAMRAN HOTEL                      1.000000             352
# BULAN HOTEL                       0.235968             102
# AL-IMRAN HOTEL                    0.187956             137
# RAMA MIDWAY GUEST HOSUE           0.030592             164
# WAZIR GUEST HIUSE RAMA ASTORE    -0.009762             101

# %%
df3.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# INDUS VIEW HOTEL                4.491071
# SHAH GUEST HOUSE                4.456790
# NOMAL RIVER VIEW GUEST HOUSE    4.333333
# PAKIZA HOTEL                    4.292237
# HIKAL HOTEL                     4.291667
# Name: rating, dtype: float64

# %%
df3.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# GHIZER BLOSSOM INN     344
# RAWAL HOTEL            300
# HIKAL HOTEL            264
# ADEEB GUEST HOUSE      254
# GILGITI FOOD YARD      250
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df3.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                                  rating
# title
# ABDULLAH NIHARI                3.984375
# ADEEB GUEST HOUSE              3.031496
# ADVENTURE HOLIDAY GUEST HOUSE  3.562500
# AKBAR GUEST HOUSE              3.942149
# AKBAR HOTEL                    3.595349

# %%
ratings['num of ratings'] = pd.DataFrame(df3.groupby('title')['rating'].count())
ratings.head()
# Out:
#                                  rating  num of ratings
# title
# ABDULLAH NIHARI                3.984375             128
# ADEEB GUEST HOUSE              3.031496             254
# ADVENTURE HOLIDAY GUEST HOUSE  3.562500             208
# AKBAR GUEST HOUSE              3.942149             121
# AKBAR HOTEL                    3.595349             215

# %%
ratings.head(5)
# Out:
#                                  rating  num of ratings
# title
# ABDULLAH NIHARI                3.984375             128
# ADEEB GUEST HOUSE              3.031496             254
# ADVENTURE HOLIDAY GUEST HOUSE  3.562500             208
# AKBAR GUEST HOUSE              3.942149             121
# AKBAR HOTEL                    3.595349             215

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df3.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    ABDULLAH NIHARI  ADEEB GUEST HOUSE  ADVENTURE HOLIDAY GUEST HOUSE  \
# user_id
# 3                    NaN                NaN                            NaN
# 4                    NaN                NaN                            NaN
# 5                    NaN                NaN                            4.0
# 6                    4.0                NaN                            NaN
# 7                    3.0                4.0                            5.0
#
# title    AKBAR GUEST HOUSE  AKBAR HOTEL  AKBAR RESTAURANT  AL MADINA HOTEL  \
# user_id
# 3                      NaN          NaN               NaN              NaN
# 4                      NaN          NaN               NaN              NaN
# 5                      NaN          NaN               NaN              3.0
# 6                      4.0          3.0               4.0              4.0
# 7                      5.0          NaN               5.0              3.0
#
# title    AL-KASHMIR HOTEL  AL-KHAIR HOHTEL  ALFALAH HOTEL GUPIS  ...  \
# user_id                                                          ...
# 3                     NaN              NaN                  NaN  ...
# 4                     NaN              NaN                  NaN  ...
# 5                     NaN              NaN                  2.0  ...
# 6                     NaN              5.0                  NaN  ...
# 7                     4.0              NaN                  NaN  ...
#
# title    TOURIST HALMET GILGIT  TOURIST HAMLET HOTEL  TOURIST WORLD HOTEL  \
# user_id
# 3                          NaN                   NaN                  NaN
# 4                          NaN                   NaN                  NaN
# 5                          NaN                   1.0                  3.0
# 6                          5.0                   NaN                  NaN
# 7                          4.0                   5.0                  3.0
#
# title    TURGIL RESORT NALTAR  UNITED HOTEL  UTOPIA HOTEL  WAEERS MAHEL HOTEL  \
# user_id
# 3                         NaN           NaN           NaN                 NaN
# 4                         NaN           NaN           NaN                 NaN
# 5                         NaN           1.0           NaN                 3.0
# 6                         4.0           NaN           NaN                 NaN
# 7                         NaN           NaN           3.0                 4.0
#
# title    YASIN HOLIDAY HOTEL GILGIT  YASIN HOLIDAY RESTAURANT GILGIT  \
# user_id
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               4.0                              4.0
# 7                               5.0                              NaN
#
# title    YASIN RESTHOUSE GILGIT
# user_id
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           3.0
# 7                           NaN
#
# [5 rows x 225 columns]

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                        rating  num of ratings
# title
# GHIZER BLOSSOM INN   3.313953             344
# RAWAL HOTEL          3.833333             300
# HIKAL HOTEL          4.291667             264
# ADEEB GUEST HOUSE    3.031496             254
# GILGITI FOOD YARD    3.884000             250
# SHAH GUEST HOUSE     4.456790             243
# SUFI HOTEL           4.121212             231
# CITI HOTEL GILGIT    3.610860             221
# PAKIZA HOTEL         4.292237             219
# PUNJAB HOTEL         3.949074             216

# %%
ratings.head()
# Out:
#                                  rating  num of ratings
# title
# ABDULLAH NIHARI                3.984375             128
# ADEEB GUEST HOUSE              3.031496             254
# ADVENTURE HOLIDAY GUEST HOUSE  3.562500             208
# AKBAR GUEST HOUSE              3.942149             121
# AKBAR HOTEL                    3.595349             215

# %%
starwars_user_ratings = moviemat['YASIN HOLIDAY HOTEL GILGIT']
liarliar_user_ratings = moviemat['GILGITI FOOD YARD']
starwars_user_ratings.head()
# Out:
# user_id
# 3    NaN
# 4    NaN
# 5    NaN
# 6    4.0
# 7    5.0
# Name: YASIN HOLIDAY HOTEL GILGIT, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                                Correlation
# title
# ABDULLAH NIHARI                   0.227411
# ADEEB GUEST HOUSE                -0.228480
# ADVENTURE HOLIDAY GUEST HOUSE     0.121643
# AKBAR GUEST HOUSE                 0.500867
# AKBAR HOTEL                       0.220457

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                             Correlation
# title
# YASIN RESTHOUSE GILGIT         1.000000
# FAKHAR GUEST HOUSE             1.000000
# YASIN HOLIDAY HOTEL GILGIT     1.000000
# HOTEL DANYORE                  0.970725
# KARAKORAM HOTEL                0.866025
# FRIENDS GARDEN                 0.866025
# RIVERDALE RESORT               0.866025
# HIGH LAND HOTEL                0.860663
# GOORGI RESTAURANT              0.814822
# PAK CHINA GATEWAY              0.770275

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                                Correlation  num of ratings
# title
# ABDULLAH NIHARI                   0.227411             128
# ADEEB GUEST HOUSE                -0.228480             254
# ADVENTURE HOLIDAY GUEST HOUSE     0.121643             208
# AKBAR GUEST HOUSE                 0.500867             121
# AKBAR HOTEL                       0.220457             215

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                   Correlation  num of ratings
# title
# AKBAR RESTAURANT     0.716864             121
# SPRINGFIELD          0.688679             126
# DAILY DOSE           0.527699             124
# PUNJAB HOTEL         0.512458             216
# AL-KHAIR HOHTEL      0.502514             148

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                    Correlation  num of ratings
# title
# GILGITI FOOD YARD     1.000000             250
# LAKE VIEW HOTEL       0.412534             162
# PAKIZA RESTAURANT     0.407541             121
# HARGISA HUT           0.391325             137
# HIKAL HOTEL           0.376576             264

# %%
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                    Correlation  num of ratings
# title
# GILGITI FOOD YARD     1.000000             250
# LAKE VIEW HOTEL       0.412534             162
# PAKIZA RESTAURANT     0.407541             121
# HARGISA HUT           0.391325             137
# HIKAL HOTEL           0.376576             264

# %%
np=(corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head())
np.values.tolist()
# Out:
# [[1.0, 250.0],
#  [0.41253380223793606, 162.0],
#  [0.40754139117391824, 121.0],
#  [0.39132468311805835, 137.0],
#  [0.3765762272269866, 264.0]]

# %%
np.columns
# Out:
# Index(['Correlation', 'num of ratings'], dtype='object')

# %%
for name in np.columns:
    print(np[name])
# Out:
# title
# GILGITI FOOD YARD    1.000000
# LAKE VIEW HOTEL      0.412534
# PAKIZA RESTAURANT    0.407541
# HARGISA HUT          0.391325
# HIKAL HOTEL          0.376576
# Name: Correlation, dtype: float64
# title
# GILGITI FOOD YARD    250
# LAKE VIEW HOTEL      162
# PAKIZA RESTAURANT    121
# HARGISA HUT          137
# HIKAL HOTEL          264
# Name: num of ratings, dtype: int64
