# %%
import numpy as np
import pandas as pd

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
# Out:
#    item_id             PLACES  \
# 0        1        BALTIT FORT
# 1        2      ULTAR GLACIER
# 2        3       ATTABAD LAKE
# 3        4  KHABASI RESIDENCE
# 4        5   SHISPARE GLACIER
#
#                                         THINGS TO DO             LOCATION  \
# 0                               POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                           TRACKING     KARIMABAD HUNZA
# 2                                   SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                           TRACKING     HASSANABAD HUNZA
#
#      CITY       TRIP                                           LAKES  \
# 0  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                             GLACIERS  \
# 0  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                        CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...

# %%
hotels_detail.shape
# Out:
# (381, 9)

# %%
g =hotels_detail.groupby("CITY")
g

# %%
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 316      317                          HALDI CONES
# 318      319                    KONDUS HOT SPRING
# 360      361                             KHARPAT
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO  LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT    ASTORE  ASTORE
# 238                                   SWIMMING,BOATING    ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...    ASTORE  ASTORE
# 240                                      NATIONAL PARK    ASTORE  ASTORE
# 316                               HIKING,STAY AND DINE  GHANCHE   ASTORE
# 318                               HIKING,STAY AND DINE  GHANCHE   ASTORE
# 360                          HISTORICAL THINGS,CULTURE   GHANCHE  ASTORE
# 362                              BOATING ,PICNIC POINT    ASTORE  ASTORE
# 371                                   SWIMMING,BOATING    ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE     ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,     ASTORE  ASTORE
#
#           TRIP                                              LAKES  \
# 229  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 316     Family                                                NaN
# 318  Adventure                                                NaN
# 360     Family                                                NaN
# 362  Adventure                                                NaN
# 371     Family                                                NaN
# 372     Family                                                NaN
# 373  Adventure                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 316                                                NaN           NaN
# 318                                                NaN           NaN
# 360                                                NaN           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 278      279            HUSHE VALLEY
# 279      280          PHANDER VALLEY
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 287      288           KHALTI VALLEY
# 288      289            YASIN VALLEY
# 289      290          PUNIYAL VALLEY
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO  LOCATION     CITY  \
# 117                                   SWIMMING,BOATING   ASTORE   ASTORE
# 120                                   SWIMMING,BOATING   ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING   ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE    PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING   ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING   ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...   ASTORE   ASTORE
# 250                                   SWIMMING,BOATING   ASTORE   ASTORE
# 253                                   SWIMMING,BOATING   ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT   ASTORE   ASTORE
# 278  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  GHANCHE   ASTORE
# 279  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   PHANDER  ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING   ASTORE   ASTORE
# 287   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE    GUPIS   ASTORE
# 288       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING    YASIN   ASTORE
# 289       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING    YASIN   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS   ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS   ASTORE   ASTORE
#
#           TRIP                                              LAKES  \
# 117  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250  Adventure                                                NaN
# 253  Adventure                                                NaN
# 273  Adventure                                                NaN
# 278  Adventure                                                NaN
# 279     Family                                                NaN
# 280     Family                                                NaN
# 281  Adventure                                                NaN
# 287     Family                                                NaN
# 288     Family                                                NaN
# 289  Adventure                                                NaN
# 291     Family                                                NaN
# 292     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 278                                                NaN           NaN
# 279                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 287                                                NaN           NaN
# 288                                                NaN           NaN
# 289                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#           TRIP                                              LAKES  \
# 132     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265  Adventure                                                NaN
# 266  Adventure                                                NaN
# 267     Family                                                NaN
# 277  Adventure                                                NaN
# 331     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
#
#
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#           TRIP                                              LAKES  \
# 149  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290  Adventure                                                NaN
# 363     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY       TRIP                                              LAKES  \
# 115  GILGIT     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  GILGIT     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  GILGIT     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  GILGIT  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  GILGIT  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..      ...        ...                                                ...
# 376  GILGIT     Family                                                NaN
# 377  GILGIT  Adventure                                                NaN
# 378  GILGIT  Adventure                                                NaN
# 379  GILGIT     Family                                                NaN
# 380  GILGIT     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY       TRIP                                           LAKES  \
# 0    HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..      ...        ...                                             ...
# 110  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
#
#
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#           TRIP                                              LAKES  \
# 128     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261  Adventure                                                NaN
# 262  Adventure                                                NaN
# 297  Adventure                                                NaN
# 307     Family                                                NaN
# 315     Family                                                NaN
# 323     Family                                                NaN
# 325  Adventure                                                NaN
# 329  Adventure                                                NaN
# 330  Adventure                                                NaN
# 332     Family                                                NaN
# 358  Adventure                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY       TRIP                                              LAKES  \
# 118  SKARDU  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SKARDU     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SKARDU     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SKARDU     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SKARDU  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..      ...        ...                                                ...
# 364  SKARDU     Family                                                NaN
# 365  SKARDU  Adventure                                                NaN
# 366  SKARDU  Adventure                                                NaN
# 367  SKARDU     Family                                                NaN
# 368  SKARDU     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [85 rows x 9 columns]

# %%
g.get_group('HUNZA ')
# Out:
#      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY       TRIP                                           LAKES  \
# 0    HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..      ...        ...                                             ...
# 110  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  HUNZA      Family  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  HUNZA   Adventure  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]

# %%
g.get_group('GILGIT')
# Out:
#      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY       TRIP                                              LAKES  \
# 115  GILGIT     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  GILGIT     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  GILGIT     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  GILGIT  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  GILGIT  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..      ...        ...                                                ...
# 376  GILGIT     Family                                                NaN
# 377  GILGIT  Adventure                                                NaN
# 378  GILGIT  Adventure                                                NaN
# 379  GILGIT     Family                                                NaN
# 380  GILGIT     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]

# %%
g.get_group('SKARDU')
# Out:
#      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY       TRIP                                              LAKES  \
# 118  SKARDU  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SKARDU     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SKARDU     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SKARDU     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SKARDU  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..      ...        ...                                                ...
# 364  SKARDU     Family                                                NaN
# 365  SKARDU  Adventure                                                NaN
# 366  SKARDU  Adventure                                                NaN
# 367  SKARDU     Family                                                NaN
# 368  SKARDU     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [85 rows x 9 columns]

# %%
g.get_group('ASTORE')
# Out:
#      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 316      317                          HALDI CONES
# 318      319                    KONDUS HOT SPRING
# 360      361                             KHARPAT
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO  LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT    ASTORE  ASTORE
# 238                                   SWIMMING,BOATING    ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...    ASTORE  ASTORE
# 240                                      NATIONAL PARK    ASTORE  ASTORE
# 316                               HIKING,STAY AND DINE  GHANCHE   ASTORE
# 318                               HIKING,STAY AND DINE  GHANCHE   ASTORE
# 360                          HISTORICAL THINGS,CULTURE   GHANCHE  ASTORE
# 362                              BOATING ,PICNIC POINT    ASTORE  ASTORE
# 371                                   SWIMMING,BOATING    ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE     ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,     ASTORE  ASTORE
#
#           TRIP                                              LAKES  \
# 229  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 316     Family                                                NaN
# 318  Adventure                                                NaN
# 360     Family                                                NaN
# 362  Adventure                                                NaN
# 371     Family                                                NaN
# 372     Family                                                NaN
# 373  Adventure                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 316                                                NaN           NaN
# 318                                                NaN           NaN
# 360                                                NaN           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN

# %%
g.get_group('GHIZER')
# Out:
#      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#           TRIP                                              LAKES  \
# 149  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290  Adventure                                                NaN
# 363     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN

# %%
g.get_group('DIAMER')
# Out:
#      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#           TRIP                                              LAKES  \
# 132     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265  Adventure                                                NaN
# 266  Adventure                                                NaN
# 267     Family                                                NaN
# 277  Adventure                                                NaN
# 331     Family                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN

# %%
g.get_group('SHIGAR')
# Out:
#      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#           TRIP                                              LAKES  \
# 128     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203     Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  Adventure  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261  Adventure                                                NaN
# 262  Adventure                                                NaN
# 297  Adventure                                                NaN
# 307     Family                                                NaN
# 315     Family                                                NaN
# 323     Family                                                NaN
# 325  Adventure                                                NaN
# 329  Adventure                                                NaN
# 330  Adventure                                                NaN
# 332     Family                                                NaN
# 358  Adventure                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN

# %%
#column_names = ['user_id', 'item_id', 'rating', 'timestamp']
#df = pd.read_csv('u.data', sep='\t', names=column_names)
#df1 = pd.read_csv('u.data', sep='\t', names=column_names)
#df2 = pd.read_csv('u.data', sep='\t', names=column_names)
#df3 = pd.read_csv('u.data', sep='\t', names=column_names)
#df4 = pd.read_csv('u.data', sep='\t', names=column_names)
#df5 = pd.read_csv('u.data', sep='\t', names=column_names)
#df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")
df1 = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")
df2 = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")
df3 = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")
df4 = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")
df5 = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")
df6 = pd.read_csv("C:\\Users\\Nova Data\\Desktop\mylist.csv")

# %%
df.head(5)
# Out:
#    user_id  item_id  rating    timestamp
# 0        0       50       5  881250949.0
# 1        0      172       5  881250949.0
# 2        0      133       1  881250949.0
# 3      196      242       3  881250949.0
# 4      186      302       3  891717742.0

# %%
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
# Out:
#    user_id  item_id  rating    timestamp             PLACES THINGS TO DO  \
# 0        0      172       5  881250949.0  KHAMUSH WATERFALL     SWIMMING
# 1      213      172       5  878955442.0  KHAMUSH WATERFALL     SWIMMING
# 2       92      172       4  875653271.0  KHAMUSH WATERFALL     SWIMMING
# 3       77      172       3  884752562.0  KHAMUSH WATERFALL     SWIMMING
# 4      194      172       3  879521474.0  KHAMUSH WATERFALL     SWIMMING
#
#   LOCATION    CITY    TRIP                                              LAKES  \
# 0   SKARDU  SKARDU  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 1   SKARDU  SKARDU  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 2   SKARDU  SKARDU  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 3   SKARDU  SKARDU  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 4   SKARDU  SKARDU  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
#
#                                             GLACIERS CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN

# %%
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
# Out:
#    user_id  item_id  rating    timestamp       PLACES  \
# 0        0       50       5  881250949.0  HUNZA WATER
# 1      290       50       5  880473582.0  HUNZA WATER
# 2       79       50       4  891271545.0  HUNZA WATER
# 3        2       50       5  888552084.0  HUNZA WATER
# 4        8       50       5  879362124.0  HUNZA WATER
#
#                     THINGS TO DO LOCATION    CITY       TRIP  \
# 0  DRINK HUNZA WATER , WATERFALL   HUNZA   HUNZA   Adventure
# 1  DRINK HUNZA WATER , WATERFALL   HUNZA   HUNZA   Adventure
# 2  DRINK HUNZA WATER , WATERFALL   HUNZA   HUNZA   Adventure
# 3  DRINK HUNZA WATER , WATERFALL   HUNZA   HUNZA   Adventure
# 4  DRINK HUNZA WATER , WATERFALL   HUNZA   HUNZA   Adventure
#
#                                             LAKES  \
# 0  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                             GLACIERS  \
# 0  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                        CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...

# %%
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
# Out:
#    user_id  item_id  rating    timestamp                   PLACES  \
# 0      249      241       5  879641194.0  FORT KING NATIONAL PARK
# 1      234      241       2  892335042.0  FORT KING NATIONAL PARK
# 2       22      241       3  878888025.0  FORT KING NATIONAL PARK
# 3       92      241       3  875655961.0  FORT KING NATIONAL PARK
# 4      158      241       4  880134445.0  FORT KING NATIONAL PARK
#
#      THINGS TO DO LOCATION    CITY    TRIP  \
# 0   NATIONAL PARK   ASTORE  ASTORE  Family
# 1   NATIONAL PARK   ASTORE  ASTORE  Family
# 2   NATIONAL PARK   ASTORE  ASTORE  Family
# 3   NATIONAL PARK   ASTORE  ASTORE  Family
# 4   NATIONAL PARK   ASTORE  ASTORE  Family
#
#                                                LAKES  \
# 0  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 1  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 2  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 3  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 4  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
#
#                                             GLACIERS CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN

# %%
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
# Out:
#    user_id  item_id  rating    timestamp          PLACES  \
# 0      196      242       3  881250949.0  BILCHAR DUBANI
# 1       63      242       3  875747190.0  BILCHAR DUBANI
# 2      226      242       5  883888671.0  BILCHAR DUBANI
# 3      154      242       3  879138235.0  BILCHAR DUBANI
# 4      306      242       5  876503793.0  BILCHAR DUBANI
#
#                             THINGS TO DO        LOCATION    CITY       TRIP  \
# 0  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  BAGROTE GILGIT  GILGIT  Adventure
# 1  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  BAGROTE GILGIT  GILGIT  Adventure
# 2  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  BAGROTE GILGIT  GILGIT  Adventure
# 3  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  BAGROTE GILGIT  GILGIT  Adventure
# 4  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  BAGROTE GILGIT  GILGIT  Adventure
#
#                                                LAKES  \
# 0  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 1  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 2  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 3  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 4  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
#
#                                             GLACIERS CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN

# %%
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
# Out:
#    user_id  item_id  rating    timestamp            PLACES THINGS TO DO  \
# 0        0      133       1  881250949.0  DIAMER BASHA DAM          DAM
# 1      297      133       4  875240090.0  DIAMER BASHA DAM          DAM
# 2      213      133       3  878955973.0  DIAMER BASHA DAM          DAM
# 3      312      133       5  891699296.0  DIAMER BASHA DAM          DAM
# 4      286      133       4  877531730.0  DIAMER BASHA DAM          DAM
#
#   LOCATION    CITY    TRIP                                              LAKES  \
# 0   DIAMER  DIAMER  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 1   DIAMER  DIAMER  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 2   DIAMER  DIAMER  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 3   DIAMER  DIAMER  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 4   DIAMER  DIAMER  Family  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
#
#                                             GLACIERS CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN

# %%
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
# Out:
#    user_id  item_id  rating    timestamp             PLACES  \
# 0      225      193       4  879539727.0  SHIGAR BUDHA ROCK
# 1        7      193       5  892135346.0  SHIGAR BUDHA ROCK
# 2       91      193       3  891439057.0  SHIGAR BUDHA ROCK
# 3      308      193       3  887737837.0  SHIGAR BUDHA ROCK
# 4      307      193       3  879205470.0  SHIGAR BUDHA ROCK
#
#                                THINGS TO DO LOCATION    CITY    TRIP  \
# 0  TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR  Family
# 1  TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR  Family
# 2  TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR  Family
# 3  TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR  Family
# 4  TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR  Family
#
#                                                LAKES  \
# 0  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 1  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 2  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 3  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 4  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
#
#                                             GLACIERS CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN

# %%
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
# Out:
#    user_id  item_id  rating    timestamp          PLACES   THINGS TO DO  \
# 0      268      231       4  875744136.0  BARODAROROKSH   PICNIC POINT
# 1      286      231       3  877532094.0  BARODAROROKSH   PICNIC POINT
# 2       82      231       2  878769815.0  BARODAROROKSH   PICNIC POINT
# 3        5      231       2  875635947.0  BARODAROROKSH   PICNIC POINT
# 4      197      231       3  891410124.0  BARODAROROKSH   PICNIC POINT
#
#   LOCATION    CITY       TRIP  \
# 0   GHIZER  GHIZER  Adventure
# 1   GHIZER  GHIZER  Adventure
# 2   GHIZER  GHIZER  Adventure
# 3   GHIZER  GHIZER  Adventure
# 4   GHIZER  GHIZER  Adventure
#
#                                                LAKES  \
# 0  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 1  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 2  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 3  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 4  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
#
#                                             GLACIERS CULTURAL FOOD
# 0  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 1  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 2  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 3  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 4  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
# Out:
# PLACES
# HUSSAINABAD BROQ MASROOR ROCK    4.248815
# SHEOSAR LAKE                     4.194268
# KHAPULA FORT                     4.187919
# BARAH LAKE                       4.121827
# KHAMUSH WATERFALL                4.115304
# Name: rating, dtype: float64

# %%
df.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
# Out:
# PLACES
# KHARPOCHO FORT            766
# DARKUT                    609
# KHAPULA FORT              596
# SARFA RANGE COLDDESERT    545
# MANTHOKHA WATERFALL       540
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('PLACES')['rating'].mean())
ratings.head()
# Out:
#                                 rating
# PLACES
# ARANDU VALLEY                 3.683962
# ASTANA OF SYED MIR MUHAMMAD   3.226891
# BARAH LAKE                    4.121827
# BASHO VALLEY                  3.541667
# BURZIL PASS                   3.859532

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('PLACES')['rating'].count())
ratings.head()
# Out:
#                                 rating  num of ratings
# PLACES
# ARANDU VALLEY                 3.683962             212
# ASTANA OF SYED MIR MUHAMMAD   3.226891             119
# BARAH LAKE                    4.121827             197
# BASHO VALLEY                  3.541667             192
# BURZIL PASS                   3.859532             299

# %%
ratings.head()
# Out:
#                                 rating  num of ratings
# PLACES
# ARANDU VALLEY                 3.683962             212
# ASTANA OF SYED MIR MUHAMMAD   3.226891             119
# BARAH LAKE                    4.121827             197
# BASHO VALLEY                  3.541667             192
# BURZIL PASS                   3.859532             299

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df.pivot_table(index='user_id',columns='PLACES',values='rating')
moviemat.head()
# Out:
# PLACES   ARANDU VALLEY  ASTANA OF SYED MIR MUHAMMAD   BARAH LAKE  \
# user_id
# 0                  NaN                           NaN         NaN
# 1                  3.0                           3.0         5.0
# 2                  4.0                           NaN         5.0
# 3                  NaN                           NaN         NaN
# 4                  NaN                           NaN         NaN
#
# PLACES   BASHO VALLEY  BURZIL PASS  CHAQCHAN MOSQUE  CHUNDA VALLEY  DARKUT  \
# user_id
# 0                 NaN          NaN              NaN            NaN     NaN
# 1                 4.0          5.0              2.0            NaN     5.0
# 2                 4.0          NaN              NaN            NaN     NaN
# 3                 NaN          NaN              NaN            4.0     5.0
# 4                 NaN          NaN              NaN            5.0     3.0
#
# PLACES   DEOSAI NATIONAL PARK  DEOSAI PLANES  ...  SALING RESORT  \
# user_id                                       ...
# 0                         NaN            NaN  ...            NaN
# 1                         1.0            5.0  ...            4.0
# 2                         NaN            NaN  ...            1.0
# 3                         3.0            NaN  ...            NaN
# 4                         4.0            NaN  ...            NaN
#
# PLACES   SARFA RANGE COLDDESERT  SATPARA LAKE SKARDU  SHEOSAR LAKE  \
# user_id
# 0                           NaN                  NaN           NaN
# 1                           5.0                  2.0           5.0
# 2                           4.0                  5.0           NaN
# 3                           NaN                  NaN           NaN
# 4                           5.0                  NaN           4.0
#
# PLACES   SHILA VALLEY  SHINGRILA RESORT  SKARDU FORT  STAK VALLEY  TSOK NALA  \
# user_id
# 0                 NaN               NaN          NaN          NaN        NaN
# 1                 NaN               4.0          NaN          4.0        5.0
# 2                 NaN               NaN          NaN          NaN        4.0
# 3                 NaN               NaN          NaN          NaN        3.0
# 4                 NaN               NaN          NaN          NaN        NaN
#
# PLACES   UPPER KACHURA LAKE
# user_id
# 0                       NaN
# 1                       3.0
# 2                       5.0
# 3                       2.0
# 4                       NaN
#
# [5 rows x 45 columns]

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                rating  num of ratings
# PLACES
# KHARPOCHO FORT               3.710183             766
# DARKUT                       3.656814             609
# KHAPULA FORT                 4.187919             596
# SARFA RANGE COLDDESERT       3.755963             545
# MANTHOKHA WATERFALL          3.785185             540
# KATPAN LAKE AND COLD DESERT  3.510557             521
# MANTHAL BUDDHA ROCK          3.841046             497
# HANJOOR                      3.917339             496
# KHAMUSH WATERFALL            4.115304             477
# SKARDU FORT                  3.668132             455

# %%
ratings.head()
# Out:
#                                 rating  num of ratings
# PLACES
# ARANDU VALLEY                 3.683962             212
# ASTANA OF SYED MIR MUHAMMAD   3.226891             119
# BARAH LAKE                    4.121827             197
# BASHO VALLEY                  3.541667             192
# BURZIL PASS                   3.859532             299

# %%
starwars_user_ratings = moviemat['RUSH LAKE']
liarliar_user_ratings = moviemat['RUSH LAKE']
starwars_user_ratings.head()
# Out:
# user_id
# 0    NaN
# 1    4.0
# 2    NaN
# 3    NaN
# 4    NaN
# Name: RUSH LAKE, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)
# Out:
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                               Correlation
# PLACES
# ARANDU VALLEY                    0.135960
# ASTANA OF SYED MIR MUHAMMAD     -0.297965
# BARAH LAKE                      -0.283552
# BASHO VALLEY                     0.180070
# BURZIL PASS                     -0.062580

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                      Correlation
# PLACES
# RUSH LAKE               1.000000
# STAK VALLEY             0.427673
# MANTHOKHA WATERFALL     0.396876
# NANGMA VELLEY           0.371645
# SHEOSAR LAKE            0.299675
# K2 BASE CAMP            0.294714
# SHILA VALLEY            0.255498
# SKARDU FORT             0.230552
# BASHO VALLEY            0.180070
# KHAMUSH WATERFALL       0.173941

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                               Correlation  num of ratings
# PLACES
# ARANDU VALLEY                    0.135960             212
# ASTANA OF SYED MIR MUHAMMAD     -0.297965             119
# BARAH LAKE                      -0.283552             197
# BASHO VALLEY                     0.180070             192
# BURZIL PASS                     -0.062580             299

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                      Correlation  num of ratings
# PLACES
# RUSH LAKE               1.000000             110
# STAK VALLEY             0.427673             103
# MANTHOKHA WATERFALL     0.396876             540
# NANGMA VELLEY           0.371645             245
# SHEOSAR LAKE            0.299675             314

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                      Correlation  num of ratings
# PLACES
# RUSH LAKE               1.000000             110
# STAK VALLEY             0.427673             103
# MANTHOKHA WATERFALL     0.396876             540
# NANGMA VELLEY           0.371645             245
# SHEOSAR LAKE            0.299675             314

# %%
df1.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
# Out:
# PLACES
# MALTAR NILT NAGAR    4.547945
# SULTAN SHAH TALIB    4.500000
# KACHELI LAKE         4.402827
# HUNZA WATER          4.363167
# RAHIMABAD NAGAR      4.282828
# Name: rating, dtype: float64

# %%
df1.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
# Out:
# PLACES
# GHASHUMALING NAGAR         614
# HUNZA WATER                581
# BALTIT FORT                435
# PASSU SAR                  414
# KHUNJERAB NATIONAL PARK    407
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df1.groupby('PLACES')['rating'].mean())
ratings.head()
# Out:
#                            rating
# PLACES
# AKYSB WOMEN ARTS MUSEUM  3.630522
# ALTIT MUSEUM             3.815152
# ARBABBUL                 3.581818
# ATTABAD LAKE             3.121951
# BABAGUNDI                3.989247

# %%
ratings['num of ratings'] = pd.DataFrame(df1.groupby('PLACES')['rating'].count())
ratings.head()
# Out:
#                            rating  num of ratings
# PLACES
# AKYSB WOMEN ARTS MUSEUM  3.630522             249
# ALTIT MUSEUM             3.815152             330
# ARBABBUL                 3.581818             110
# ATTABAD LAKE             3.121951              82
# BABAGUNDI                3.989247              93

# %%
ratings.head()
# Out:
#                            rating  num of ratings
# PLACES
# AKYSB WOMEN ARTS MUSEUM  3.630522             249
# ALTIT MUSEUM             3.815152             330
# ARBABBUL                 3.581818             110
# ATTABAD LAKE             3.121951              82
# BABAGUNDI                3.989247              93

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df1.pivot_table(index='user_id',columns='PLACES',values='rating')
moviemat.head()
# Out:
# PLACES   AKYSB WOMEN ARTS MUSEUM  ALTIT MUSEUM  ARBABBUL  ATTABAD LAKE  \
# user_id
# 0                            NaN           NaN       NaN           NaN
# 1                            3.0           3.0       5.0           4.0
# 2                            NaN           NaN       NaN           NaN
# 4                            NaN           NaN       NaN           NaN
# 5                            NaN           1.0       NaN           NaN
#
# PLACES   BABAGUNDI   BALTIT FORT  BAROKHOON  BARPU  BARTAR  BATURA GLACIER  \
# user_id
# 0               NaN          NaN        NaN    NaN     NaN             NaN
# 1               5.0          NaN        4.0    5.0     5.0             3.0
# 2               NaN          4.0        NaN    NaN     NaN             NaN
# 4               NaN          NaN        NaN    NaN     NaN             NaN
# 5               NaN          4.0        2.0    NaN     NaN             4.0
#
# PLACES   ...  SULTAN SHAH TALIB  SUNRISE VEW  SUNSET VIEW  \
# user_id  ...
# 0        ...                NaN          NaN          NaN
# 1        ...                5.0          1.0          4.0
# 2        ...                NaN          NaN          NaN
# 4        ...                NaN          NaN          NaN
# 5        ...                NaN          4.0          NaN
#
# PLACES   SUSPENSION BRIDGE HISPER NAGAR  THAGHA FARI MINAPIN NAGAR  \
# user_id
# 0                                   NaN                        NaN
# 1                                   3.0                        5.0
# 2                                   NaN                        NaN
# 4                                   NaN                        NaN
# 5                                   NaN                        NaN
#
# PLACES   THAMO HARA NAGAR PROPER  THENGI  TOP   ULTAR GLACIER  WAKHI MUSEM
# user_id
# 0                            NaN     NaN   NaN            NaN          NaN
# 1                            NaN     5.0   3.0            3.0          2.0
# 2                            NaN     4.0   NaN            NaN          NaN
# 4                            NaN     NaN   NaN            NaN          NaN
# 5                            NaN     NaN   NaN            3.0          1.0
#
# [5 rows x 114 columns]

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                            rating  num of ratings
# PLACES
# GHASHUMALING NAGAR       4.086319             614
# HUNZA WATER              4.363167             581
# BALTIT FORT              3.855172             435
# PASSU SAR                3.818841             414
# KHUNJERAB NATIONAL PARK  4.088452             407
# RAHIMABAD NAGAR          4.282828             396
# DII                      4.005797             345
# ALTIT MUSEUM             3.815152             330
# HARAI                    4.136508             315
# EAGLE NEST               3.421569             306

# %%
ratings.head()
# Out:
#                            rating  num of ratings
# PLACES
# AKYSB WOMEN ARTS MUSEUM  3.630522             249
# ALTIT MUSEUM             3.815152             330
# ARBABBUL                 3.581818             110
# ATTABAD LAKE             3.121951              82
# BABAGUNDI                3.989247              93

# %%
starwars_user_ratings = moviemat['ARBABBUL']
liarliar_user_ratings = moviemat['AKYSB WOMEN ARTS MUSEUM']
starwars_user_ratings.head()
# Out:
# user_id
# 0    NaN
# 1    5.0
# 2    NaN
# 4    NaN
# 5    NaN
# Name: ARBABBUL, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                          Correlation
# PLACES
# AKYSB WOMEN ARTS MUSEUM     0.004928
# ALTIT MUSEUM                0.024898
# ARBABBUL                    1.000000
# ATTABAD LAKE                0.262829
# BABAGUNDI                   0.394032

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                          Correlation
# PLACES
# ARBABBUL                    1.000000
# BARPU                       0.667017
# BARTAR                      0.636364
# BATURA GLACIER              0.580508
# HASANABAD LAKE              0.501847
# SANGEMARMAR SAR             0.491745
# CHALT                       0.445430
# QURBAN CRICKET STADIUM      0.431934
# KHUNJERAB PASS              0.426621
# BUALTAR GLACIER             0.419828

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                          Correlation  num of ratings
# PLACES
# AKYSB WOMEN ARTS MUSEUM     0.004928             249
# ALTIT MUSEUM                0.024898             330
# ARBABBUL                    1.000000             110
# ATTABAD LAKE                0.262829              82
# BABAGUNDI                   0.394032              93

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                  Correlation  num of ratings
# PLACES
# ARBABBUL            1.000000             110
# SANGEMARMAR SAR     0.491745             184
# KHUNJERAB PASS      0.426621             152
# BOYBAR              0.372165             101
# GHALBISHI           0.354355             288

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                          Correlation  num of ratings
# PLACES
# AKYSB WOMEN ARTS MUSEUM     1.000000             249
# HARAI                       0.378041             315
# GIRCHA BUL                  0.365476             214
# HUNZA PEAK                  0.353885             304
# MISGAR POWER                0.346307             156

# %%
df2.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
# Out:
# PLACES
# DAR LAY LAKE ASTORE                    3.507772
# FORT KING NATIONAL PARK                3.433566
# BYARSA LAKE                            3.320312
# PIONEER SETTLEMENT FOR CREATIVE ART    2.816327
# Name: rating, dtype: float64

# %%
df2.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
# Out:
# PLACES
# BYARSA LAKE                            256
# PIONEER SETTLEMENT FOR CREATIVE ART    196
# DAR LAY LAKE ASTORE                    193
# FORT KING NATIONAL PARK                143
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df2.groupby('PLACES')['rating'].mean())
ratings.head()
# Out:
#                                        rating
# PLACES
# BYARSA LAKE                          3.320312
# DAR LAY LAKE ASTORE                  3.507772
# FORT KING NATIONAL PARK              3.433566
# PIONEER SETTLEMENT FOR CREATIVE ART  2.816327

# %%
ratings['num of ratings'] = pd.DataFrame(df2.groupby('PLACES')['rating'].count())
ratings.head()
# Out:
#                                        rating  num of ratings
# PLACES
# BYARSA LAKE                          3.320312             256
# DAR LAY LAKE ASTORE                  3.507772             193
# FORT KING NATIONAL PARK              3.433566             143
# PIONEER SETTLEMENT FOR CREATIVE ART  2.816327             196

# %%
ratings.head()
# Out:
#                                        rating  num of ratings
# PLACES
# BYARSA LAKE                          3.320312             256
# DAR LAY LAKE ASTORE                  3.507772             193
# FORT KING NATIONAL PARK              3.433566             143
# PIONEER SETTLEMENT FOR CREATIVE ART  2.816327             196

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df2.pivot_table(index='user_id',columns='PLACES',values='rating')
moviemat.head()
# Out:
# PLACES   BYARSA LAKE  DAR LAY LAKE ASTORE  FORT KING NATIONAL PARK  \
# user_id
# 1                4.0                  NaN                 4.000000
# 5                3.0             3.333333                 1.666667
# 7                3.0                  NaN                 4.000000
# 10               4.0                  NaN                      NaN
# 11               4.0             4.000000                 4.000000
#
# PLACES   PIONEER SETTLEMENT FOR CREATIVE ART
# user_id
# 1                                        3.0
# 5                                        3.0
# 7                                        NaN
# 10                                       NaN
# 11                                       NaN

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                        rating  num of ratings
# PLACES
# BYARSA LAKE                          3.320312             256
# PIONEER SETTLEMENT FOR CREATIVE ART  2.816327             196
# DAR LAY LAKE ASTORE                  3.507772             193
# FORT KING NATIONAL PARK              3.433566             143

# %%
ratings.head()
# Out:
#                                        rating  num of ratings
# PLACES
# BYARSA LAKE                          3.320312             256
# DAR LAY LAKE ASTORE                  3.507772             193
# FORT KING NATIONAL PARK              3.433566             143
# PIONEER SETTLEMENT FOR CREATIVE ART  2.816327             196

# %%
starwars_user_ratings = moviemat['DAR LAY LAKE ASTORE']
liarliar_user_ratings = moviemat['FORT KING NATIONAL PARK']
starwars_user_ratings.head()
# Out:
# user_id
# 1          NaN
# 5     3.333333
# 7          NaN
# 10         NaN
# 11    4.000000
# Name: DAR LAY LAKE ASTORE, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                                      Correlation
# PLACES
# BYARSA LAKE                             0.026211
# DAR LAY LAKE ASTORE                     1.000000
# FORT KING NATIONAL PARK                 0.236493
# PIONEER SETTLEMENT FOR CREATIVE ART     0.054834

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                      Correlation
# PLACES
# DAR LAY LAKE ASTORE                     1.000000
# FORT KING NATIONAL PARK                 0.236493
# PIONEER SETTLEMENT FOR CREATIVE ART     0.054834
# BYARSA LAKE                             0.026211

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                                      Correlation  num of ratings
# PLACES
# BYARSA LAKE                             0.026211             256
# DAR LAY LAKE ASTORE                     1.000000             193
# FORT KING NATIONAL PARK                 0.236493             143
# PIONEER SETTLEMENT FOR CREATIVE ART     0.054834             196

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                      Correlation  num of ratings
# PLACES
# DAR LAY LAKE ASTORE                     1.000000             193
# FORT KING NATIONAL PARK                 0.236493             143
# PIONEER SETTLEMENT FOR CREATIVE ART     0.054834             196
# BYARSA LAKE                             0.026211             256

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                      Correlation  num of ratings
# PLACES
# FORT KING NATIONAL PARK                 1.000000             143
# DAR LAY LAKE ASTORE                     0.236493             193
# BYARSA LAKE                             0.228739             256
# PIONEER SETTLEMENT FOR CREATIVE ART     0.040627             196

# %%
df3.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
# Out:
# PLACES
# NANGMA VELLEY     4.459459
# SATORO VALLEY     4.153846
# BAGROTE VALLEY    4.020161
# BROAD PEAK        3.984848
# MUZTAGH           3.914110
# Name: rating, dtype: float64

# %%
df3.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
# Out:
# PLACES
# KUTWAL LAKE               760
# PERISHING                 720
# SATRANGI LAKE             580
# JAGIR BASEEN              545
# KUTWAL KARAMOSH VALLEY    512
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df3.groupby('PLACES')['rating'].mean())
ratings.head()
# Out:
#                      rating
# PLACES
# BAGROTE GRASSLAND  3.292398
# BAGROTE VALLEY     4.020161
# BILCHAR DUBANI     3.739130
# BROAD PEAK         3.984848
# BUBIN PASS         3.392405

# %%
ratings['num of ratings'] = pd.DataFrame(df3.groupby('PLACES')['rating'].count())
ratings.head()
# Out:
#                      rating  num of ratings
# PLACES
# BAGROTE GRASSLAND  3.292398             342
# BAGROTE VALLEY     4.020161             248
# BILCHAR DUBANI     3.739130             138
# BROAD PEAK         3.984848             462
# BUBIN PASS         3.392405             158

# %%
ratings.head()
# Out:
#                      rating  num of ratings
# PLACES
# BAGROTE GRASSLAND  3.292398             342
# BAGROTE VALLEY     4.020161             248
# BILCHAR DUBANI     3.739130             138
# BROAD PEAK         3.984848             462
# BUBIN PASS         3.392405             158

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df3.pivot_table(index='user_id',columns='PLACES',values='rating')
moviemat.head()
# Out:
# PLACES   BAGROTE GRASSLAND  BAGROTE VALLEY  BILCHAR DUBANI  BROAD PEAK  \
# user_id
# 1                      2.0             NaN             5.0         4.0
# 2                      NaN             5.0             5.0         NaN
# 3                      1.0             NaN             NaN         NaN
# 4                      NaN             NaN             NaN         NaN
# 5                      1.0             NaN             3.0         NaN
#
# PLACES   BUBIN PASS  CHARI KAND  CHILAS ROCK PAINTAINGS  CHINAR BAGH  \
# user_id
# 1               3.0         3.5                     NaN          3.0
# 2               NaN         NaN                     NaN          NaN
# 3               3.0         NaN                     NaN          3.0
# 4               NaN         NaN                     NaN          NaN
# 5               NaN         NaN                     NaN          NaN
#
# PLACES   CHURKA VALLEY  DANYORE SUSPENSION BRIDE  ...  SHANDOOR  \
# user_id                                           ...
# 1                  4.0                  1.333333  ...       5.0
# 2                  NaN                       NaN  ...       NaN
# 3                  NaN                       NaN  ...       5.0
# 4                  NaN                       NaN  ...       NaN
# 5                  4.0                  1.000000  ...       NaN
#
# PLACES   SHANDOOR POLO GROUND  SHER QILA  SHOUNTER  SHUL-E-YAL  SHYOK RIVER  \
# user_id
# 1                         5.0        4.0       5.0         4.0          5.0
# 2                         NaN        NaN       NaN         NaN          NaN
# 3                         NaN        1.0       1.0         NaN          NaN
# 4                         3.0        NaN       NaN         NaN          NaN
# 5                         NaN        NaN       4.0         NaN          NaN
#
# PLACES   SOZGUNG LAKE  THALEY VALLEY  THREE MOUNTAIN JUNCTION   YAADGHAR CHOWK
# user_id
# 1                 4.0            5.0                       2.0             3.0
# 2                 NaN            NaN                       4.0             NaN
# 3                 NaN            NaN                       NaN             4.0
# 4                 5.0            NaN                       NaN             NaN
# 5                 2.0            NaN                       1.0             NaN
#
# [5 rows x 53 columns]

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                             rating  num of ratings
# PLACES
# KUTWAL LAKE               3.710526             760
# PERISHING                 3.233333             720
# SATRANGI LAKE             3.641379             580
# JAGIR BASEEN              3.866055             545
# KUTWAL KARAMOSH VALLEY    3.460938             512
# BROAD PEAK                3.984848             462
# RAKAPOSHI BASE CAMP 2     3.660793             454
# THREE MOUNTAIN JUNCTION   3.611111             432
# CHURKA VALLEY             3.588095             420
# MACHULU LA                3.328612             353

# %%
ratings.head()
# Out:
#                      rating  num of ratings
# PLACES
# BAGROTE GRASSLAND  3.292398             342
# BAGROTE VALLEY     4.020161             248
# BILCHAR DUBANI     3.739130             138
# BROAD PEAK         3.984848             462
# BUBIN PASS         3.392405             158

# %%
starwars_user_ratings = moviemat['BAGROTE VALLEY']
liarliar_user_ratings = moviemat['BILCHAR DUBANI']
starwars_user_ratings.head()
# Out:
# user_id
# 1    NaN
# 2    5.0
# 3    NaN
# 4    NaN
# 5    NaN
# Name: BAGROTE VALLEY, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                    Correlation
# PLACES
# BAGROTE GRASSLAND    -0.042784
# BAGROTE VALLEY        1.000000
# BILCHAR DUBANI        0.248104
# BROAD PEAK            0.090105
# BUBIN PASS            0.031668

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                       Correlation
# PLACES
# BAGROTE VALLEY           1.000000
# SOZGUNG LAKE             0.478918
# DAR VIEW POINT           0.472480
# THALEY VALLEY            0.413878
# GUPIS FORT               0.369596
# KUTWAL LAKE              0.352695
# YAADGHAR CHOWK           0.346850
# SHOUNTER                 0.343496
# SHANDOOR POLO GROUND     0.340429
# LALIK JAAN STADUIM       0.330961

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                    Correlation  num of ratings
# PLACES
# BAGROTE GRASSLAND    -0.042784             342
# BAGROTE VALLEY        1.000000             248
# BILCHAR DUBANI        0.248104             138
# BROAD PEAK            0.090105             462
# BUBIN PASS            0.031668             158

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                 Correlation  num of ratings
# PLACES
# BAGROTE VALLEY     1.000000             248
# SOZGUNG LAKE       0.478918             206
# DAR VIEW POINT     0.472480             118
# THALEY VALLEY      0.413878             136
# GUPIS FORT         0.369596             323

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                     Correlation  num of ratings
# PLACES
# BILCHAR DUBANI         1.000000             138
# LALIK JAAN STADUIM     0.416173             258
# MUZTAGH                0.298303             326
# MONUMENT OF GILGIT     0.287134             340
# MUGHALMINAR GILGIT     0.264652             163

# %%
df4.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
# Out:
# PLACES
# DASSU GEMSTONE MINES    4.264916
# DASSU DAME              4.225806
# MUZTAGH                 4.216216
# RAIKOT BRIDGE           3.884328
# DIAMER BASHA DAM        3.653465
# Name: rating, dtype: float64

# %%
df4.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
# Out:
# PLACES
# RAIKOT BRIDGE           536
# DASSU GEMSTONE MINES    419
# DASSU DAME              217
# DIAMER BASHA DAM        202
# MAZINO PASS             146
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df4.groupby('PLACES')['rating'].mean())
ratings.head()
# Out:
#                         rating
# PLACES
# DASSU DAME            4.225806
# DASSU GEMSTONE MINES  4.264916
# DIAMER BASHA DAM      3.653465
# FAIRY MEADOWS DIAMER  2.774436
# MAZINO PASS           3.431507

# %%
ratings['num of ratings'] = pd.DataFrame(df4.groupby('PLACES')['rating'].count())
ratings.head()
# Out:
#                         rating  num of ratings
# PLACES
# DASSU DAME            4.225806             217
# DASSU GEMSTONE MINES  4.264916             419
# DIAMER BASHA DAM      3.653465             202
# FAIRY MEADOWS DIAMER  2.774436             133
# MAZINO PASS           3.431507             146

# %%
ratings.head()
# Out:
#                         rating  num of ratings
# PLACES
# DASSU DAME            4.225806             217
# DASSU GEMSTONE MINES  4.264916             419
# DIAMER BASHA DAM      3.653465             202
# FAIRY MEADOWS DIAMER  2.774436             133
# MAZINO PASS           3.431507             146

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df4.pivot_table(index='user_id',columns='PLACES',values='rating')
moviemat.head()
# Out:
# PLACES   DASSU DAME   DASSU GEMSTONE MINES  DIAMER BASHA DAM  \
# user_id
# 0                NaN                   NaN               1.0
# 1                4.0                   5.0               1.0
# 2                NaN                   NaN               NaN
# 3                NaN                   NaN               NaN
# 5                4.0                   NaN               NaN
#
# PLACES   FAIRY MEADOWS DIAMER  MAZINO PASS  MUZTAGH  RAIKOT BRIDGE
# user_id
# 0                         NaN          NaN      NaN            NaN
# 1                         2.0          NaN      3.0            4.0
# 2                         3.0          NaN      NaN            NaN
# 3                         NaN          1.0      NaN            3.0
# 5                         1.0          NaN      NaN            4.0

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                         rating  num of ratings
# PLACES
# RAIKOT BRIDGE         3.884328             536
# DASSU GEMSTONE MINES  4.264916             419
# DASSU DAME            4.225806             217
# DIAMER BASHA DAM      3.653465             202
# MAZINO PASS           3.431507             146
# FAIRY MEADOWS DIAMER  2.774436             133
# MUZTAGH               4.216216             111

# %%
ratings.head()
# Out:
#                         rating  num of ratings
# PLACES
# DASSU DAME            4.225806             217
# DASSU GEMSTONE MINES  4.264916             419
# DIAMER BASHA DAM      3.653465             202
# FAIRY MEADOWS DIAMER  2.774436             133
# MAZINO PASS           3.431507             146

# %%
starwars_user_ratings = moviemat['FAIRY MEADOWS DIAMER']
liarliar_user_ratings = moviemat['DASSU GEMSTONE MINES']
starwars_user_ratings.head()
# Out:
# user_id
# 0    NaN
# 1    2.0
# 2    3.0
# 3    NaN
# 5    1.0
# Name: FAIRY MEADOWS DIAMER, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                       Correlation
# PLACES
# DASSU DAME              -0.127486
# DASSU GEMSTONE MINES     0.341022
# DIAMER BASHA DAM         0.544455
# FAIRY MEADOWS DIAMER     1.000000
# MAZINO PASS              0.544184

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                       Correlation
# PLACES
# FAIRY MEADOWS DIAMER     1.000000
# DIAMER BASHA DAM         0.544455
# MAZINO PASS              0.544184
# DASSU GEMSTONE MINES     0.341022
# MUZTAGH                  0.194182
# RAIKOT BRIDGE           -0.094979
# DASSU DAME              -0.127486

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                       Correlation  num of ratings
# PLACES
# DASSU DAME              -0.127486             217
# DASSU GEMSTONE MINES     0.341022             419
# DIAMER BASHA DAM         0.544455             202
# FAIRY MEADOWS DIAMER     1.000000             133
# MAZINO PASS              0.544184             146

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                       Correlation  num of ratings
# PLACES
# FAIRY MEADOWS DIAMER     1.000000             133
# DIAMER BASHA DAM         0.544455             202
# MAZINO PASS              0.544184             146
# DASSU GEMSTONE MINES     0.341022             419
# MUZTAGH                  0.194182             111

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                       Correlation  num of ratings
# PLACES
# DASSU GEMSTONE MINES     1.000000             419
# FAIRY MEADOWS DIAMER     0.341022             133
# DIAMER BASHA DAM         0.178725             202
# RAIKOT BRIDGE            0.168971             536
# DASSU DAME               0.161800             217
