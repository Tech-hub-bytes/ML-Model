# %%
import numpy as np
import pandas as pd

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
hotels_detail.head()
# Out:
#    item_id                title          LOCATION  \
# 0        1     HUNZA VIEW HOTEL  KARIM ABAD HUNZA
# 1        2  HOTEL HUNZA EMBASSY  KARIM ABAD HUNZA
# 2        3         DARBAR HOTEL  KARIM ABAD HUNZA
# 3        4           HAIDER INN     ALIABAD HUNZA
# 4        5     HUNZA SERENA INN  KARIM ABAD HUNZA
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES   CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
# ...

# %%
hotels_detail.shape
# Out:
# (1444, 8)

# %%
g =hotels_detail.groupby("CITY")
g

# %%
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
# Out:
# city: ASTORE
#
#
# data:       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...

# %%
g.get_group('HUNZA')
# Out:
#       item_id                title           LOCATION  \
# 0           1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1           2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2           3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3           4           HAIDER INN      ALIABAD HUNZA
# 4           5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ...       ...                  ...                ...
# 1055     1056   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 1056     1057   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 1057     1058           WHITE ROCK  SHISKAT GOJAL HUN
# 1058     1059    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 1059     1060        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                               ROOM TYPE  \
# 0     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...

# %%
g.get_group('ASTORE')
# Out:
#       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...

# %%
g.get_group('GILGIT')
# Out:
#       item_id                  title                   LOCATION  \
# 338       339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339       340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340       341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341       342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342       343             PARK HOTEL        AIRPORT ROAD GILGIT
# ...       ...                    ...                        ...
# 1283     1284     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 1284     1285  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 1285     1286         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 1286     1287   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 1287     1288        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                               ROOM TYPE  \
# 338   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...

# %%
g.get_group('SKARDU')
# Out:
#       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...

# %%
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
hotels_list.head(15)
# Out:
#     item_id ROOM/NIGHT  STANDRED  NO OF ROOMS  BUDGET  DAYS
# 0         1      10000      2300           18  50,000     3
# 1         2      10000      3500           20  50,000     4
# 2         3      19000      5000           15  50,000     2
# 3         4      12000      4500           10  50,000     7
# 4         5      13000      3500           28  50,000     6
# 5         6      12000      3000           15  50,000     5
# 6         7      10000      4000           15  50,000     4
# 7         8      13000      9000           15  50,000     4
# 8         9      11000      7000           17  50,000     3
# 9        10      12000      4300           13  50,000     4
# 10       11      13000      3400           12  50,000     5
# 11       12       9000      8500           12  50,000     3
# 12       13       5000      1000           10  50,000     4
# 13       14      20000      3500           20  50,000     7
# 14       15      11000      3000           11  40,000     3

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)

# %%
df.head(5)
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp       title             LOCATION  \
# 0      278      603       5  891295330  SKARDU INN  COLLOGE ROAD SKARDU
# 1      128      603       5  879966839  SKARDU INN  COLLOGE ROAD SKARDU
# 2       42      603       4  881107502  SKARDU INN  COLLOGE ROAD SKARDU
# 3       90      603       5  891385132  SKARDU INN  COLLOGE ROAD SKARDU
# 4       44      603       4  878347420  SKARDU INN  COLLOGE ROAD SKARDU
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...

# %%
df = pd.merge(df,hotels_list,on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp       title             LOCATION  \
# 0      278      603       5  891295330  SKARDU INN  COLLOGE ROAD SKARDU
# 1      128      603       5  879966839  SKARDU INN  COLLOGE ROAD SKARDU
# 2       42      603       4  881107502  SKARDU INN  COLLOGE ROAD SKARDU
# 3       90      603       5  891385132  SKARDU INN  COLLOGE ROAD SKARDU
# 4       44      603       4  878347420  SKARDU INN  COLLOGE ROAD SKARDU
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...

# %%
df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
df1.head()
# Out:
#    user_id  item_id  rating  timestamp       title       LOCATION  \
# 0        0       50       5  881250949  ALAM LODGE  ALIABAD HUNZA
# 1      290       50       5  880473582  ALAM LODGE  ALIABAD HUNZA
# 2       79       50       4  891271545  ALAM LODGE  ALIABAD HUNZA
# 3        2       50       5  888552084  ALAM LODGE  ALIABAD HUNZA
# 4        8       50       5  879362124  ALAM LODGE  ALIABAD HUNZA
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES   CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ...

# %%
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
# Out:
#    user_id  item_id  rating  timestamp        title  \
# 0      254     1444       3  886475558  THE KITCHEN
# 1      230     1444       2  880485726  THE KITCHEN
# 2      263     1444       3  891299949  THE KITCHEN
# 3      380     1444       1  885480795  THE KITCHEN
# 4      495     1444       2  888637018  THE KITCHEN
#
#                     LOCATION  \
# 0  ASTORE VALLEY ROAD ASTORE
# 1  ASTORE VALLEY ROAD ASTORE
# 2  ASTORE VALLEY ROAD ASTORE
# 3  ASTORE VALLEY ROAD ASTORE
# 4  ASTORE VALLEY ROAD ASTORE
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# ...

# %%
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
# Out:
#    user_id  item_id  rating  timestamp              title  \
# 0       22      377       1  878887116  PALACE RESTAURANT
# 1        5      377       1  878844615  PALACE RESTAURANT
# 2      314      377       3  877890982  PALACE RESTAURANT
# 3       13      377       1  882399219  PALACE RESTAURANT
# 4      222      377       1  881060205  PALACE RESTAURANT
#
#                LOCATION                                          ROOM TYPE  \
# 0  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  MADINA MARKET GILGIT  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
# %matplotlib inline

# %%
df.groupby(['title'])['rating'].mean().sort_values(ascending=False).head()
df.columns
# Out:
# Index(['user_id', 'item_id', 'rating', 'timestamp', 'title', 'LOCATION',
#        'ROOM TYPE', 'NEAR FACILITIES', 'CITY', 'PARKING', 'REVIEWS',
#        'ROOM/NIGHT', 'STANDRED', 'NO OF ROOMS', 'BUDGET', 'DAYS'],
#       dtype='object')

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# SKARDU INN             441
# HOTEL HARGISA          287
# SKARDU VILAS           273
# SEHRISH GUEST HOUSE    262
# GREEN GUEST HOUSE      229
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
x=df.groupby('title')['rating'].mean()
print(x)
y=pd.DataFrame(x)
y.head()
y.columns
# Out:
# title
# ADVENTURE GHAZI RESORT          3.877551
# AL-YOSUF BANQUET                3.989474
# ASTORE INN HOTEL                3.581395
# BALTISTAN CONTINENTAL HOTEL     3.364706
# BALTISTAN MOUNTAIN CHALET       2.930233
#                                   ...
# SNOWLAND PALACE SKARDU          3.720000
# SUMMIT RESTAURANT               2.952381
# TAJ MAHAL HOTEL                 2.509091
# TIBET HOTEL SHANGRILA SKARDU    2.909091
# YAK TAIL RESORT                 2.250000
# Name: rating, Length: 81, dtype: float64
# Index(['rating'], dtype='object')

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                                rating  num of ratings
# title
# ADVENTURE GHAZI RESORT       3.877551              49
# AL-YOSUF BANQUET             3.989474             190
# ASTORE INN HOTEL             3.581395              43
# BALTISTAN CONTINENTAL HOTEL  3.364706              85
# BALTISTAN MOUNTAIN CHALET    2.930233             129

# %%
ratings.head()
# Out:
#                                rating  num of ratings
# title
# ADVENTURE GHAZI RESORT       3.877551              49
# AL-YOSUF BANQUET             3.989474             190
# ASTORE INN HOTEL             3.581395              43
# BALTISTAN CONTINENTAL HOTEL  3.364706              85
# BALTISTAN MOUNTAIN CHALET    2.930233             129

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
ratings['rating'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')
moviemat.head()
# Out:
# title    ADVENTURE GHAZI RESORT  AL-YOSUF BANQUET  ASTORE INN HOTEL  \
# user_id
# 7                           NaN               4.0               5.0
# 8                           NaN               NaN               NaN
# 9                           NaN               NaN               NaN
# 10                          5.0               NaN               4.0
# 11                          NaN               5.0               NaN
#
# title    BALTISTAN CONTINENTAL HOTEL  BALTISTAN MOUNTAIN CHALET  \
# user_id
# 7                                3.0                        2.5
# 8                                NaN                        NaN
# 9                                NaN                        NaN
# 10                               NaN                        4.0
# 11                               3.0                        3.0
#
# title    BALTISTAN VILLAGE GUEST HOUSE  BALTISTAN VILLAGE RESTAURANT  \
# user_id
# ...

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                         rating  num of ratings
# title
# SKARDU INN            4.108844             441
# HOTEL HARGISA         3.557491             287
# SKARDU VILAS          3.336996             273
# SEHRISH GUEST HOUSE   3.164122             262
# GREEN GUEST HOUSE     2.820961             229
# SKARDU RESTAURANT     3.923445             209
# INDUS MOTEL           3.555000             200
# SARFARANGI HOTEL      3.535354             198
# CAPRAFAL GUEST HOUSE  3.593909             197
# AL-YOSUF BANQUET      3.989474             190

# %%
ratings.head()
# Out:
#                                rating  num of ratings
# title
# ADVENTURE GHAZI RESORT       3.877551              49
# AL-YOSUF BANQUET             3.989474             190
# ASTORE INN HOTEL             3.581395              43
# BALTISTAN CONTINENTAL HOTEL  3.364706              85
# BALTISTAN MOUNTAIN CHALET    2.930233             129

# %%
starwars_user_ratings = moviemat['SKARDU INN']
liarliar_user_ratings = moviemat['SKARDU RESTAURANT']
starwars_user_ratings.head()
# Out:
# user_id
# 7     4.5
# 8     NaN
# 9     NaN
# 10    5.0
# 11    4.0
# Name: SKARDU INN, dtype: float64

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
similar_to_liarliar = moviemat.corrwith(liarliar_user_ratings)

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars.head()
# Out:
#                              Correlation
# title
# ADVENTURE GHAZI RESORT          0.127014
# AL-YOSUF BANQUET                0.242984
# ASTORE INN HOTEL                0.476680
# BALTISTAN CONTINENTAL HOTEL     0.278073
# BALTISTAN MOUNTAIN CHALET       0.192572

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                               Correlation
# title
# SKARDU INN                       1.000000
# PTDC K2 MOTEL SKARDU             1.000000
# HOTEL MOUNTAIN LODGE             0.719237
# MIR HOTEL                        0.712621
# HOTEL MASHABRUM                  0.683690
# TIBET HOTEL SHANGRILA SKARDU     0.629704
# SHALIMAR HOTEL SKARDU            0.603102
# FIVE STAR RESTAURANT             0.492010
# ASTORE INN HOTEL                 0.476680
# HARGISA HUT                      0.457125

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                              Correlation  num of ratings
# title
# ADVENTURE GHAZI RESORT          0.127014              49
# AL-YOSUF BANQUET                0.242984             190
# ASTORE INN HOTEL                0.476680              43
# BALTISTAN CONTINENTAL HOTEL     0.278073              85
# BALTISTAN MOUNTAIN CHALET       0.192572             129

# %%
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head(10)
# Out:
#                                 Correlation  num of ratings
# title
# SKARDU INN                         1.000000             441
# FIVE STAR RESTAURANT               0.492010             172
# INDUS VIEW HOTEL                   0.434116             126
# GHAZI HOTEL LAKE UPPER KACHURA     0.385633             136
# SKARDU RESTAURANT                  0.372378             209
# FOOD STREET API XHOQ SKARDU        0.368534             157
# HILTON INTERNATIONAL HOTEL         0.343649             174
# SHALIMAR RESTAURANT                0.326678             175
# PARADISE CITY HOTEL                0.319503             115
# SKARDU VILAS                       0.291530             273

# %%
corr_liarliar = pd.DataFrame(similar_to_liarliar,columns=['Correlation'])
corr_liarliar.dropna(inplace=True)
corr_liarliar = corr_liarliar.join(ratings['num of ratings'])
corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head(10)
# Out:
#                                 Correlation  num of ratings
# title
# SKARDU RESTAURANT                  1.000000             209
# GHAZI HOTEL LAKE UPPER KACHURA     0.661444             136
# HOTEL RIVER VIEW SHIGER            0.625667             115
# CONTINENTAL GUEST HOUSE SKARDU     0.509021             121
# HOTEL DE TRANGO                    0.506032             142
# FIVE STAR RESTAURANT               0.406023             172
# HOTEL SAFARNGIA RESORT             0.398817             103
# HOTEL HIMALAYA SKARDU              0.391122             148
# SKARDU INN                         0.372378             441
# CAPRAFAL GUEST HOUSE               0.360937             197

# %%
corr_liarliar.loc['SKARDU RESTAURANT']
# Out:
# Correlation         1.0
# num of ratings    209.0
# Name: SKARDU RESTAURANT, dtype: float64

# %%
corr_liarliar.loc['HOTEL RIVER VIEW SHIGER']
# Out:
# Correlation         0.625667
# num of ratings    115.000000
# Name: HOTEL RIVER VIEW SHIGER, dtype: float64

# %%
corr_liarliar.to_json()
# Out:
# '{"Correlation":{"ADVENTURE GHAZI RESORT":0.646220845,"AL-YOSUF BANQUET":0.3380705252,"ASTORE INN HOTEL":0.4351638913,"BALTISTAN CONTINENTAL HOTEL":0.3651051115,"BALTISTAN MOUNTAIN CHALET":0.3067227897,"BALTISTAN VILLAGE RESTAURANT":0.1758582975,"BELLA VISTA ":0.0106464491,"CANDELA RESORT":0.5136831857,"CAPRAFAL GUEST HOUSE":0.3609371261,"CAPRAFAL HOTEL":0.4336487412,"CAPRAFAL RESTAURANT":0.3547350355,"CITY INN HOTEL":-0.9622504486,"CONCORDIA MOTEL BALTISTAN":0.4516170171,"CONTINENTAL GUEST HOUSE SKARDU":0.5090213674,"DEOSAI GATEWAY HOTEL":0.4489318184,"FIVE STAR GUEST HOUSE":0.5809410132,"FIVE STAR RESTAURANT":0.4060225329,"FOOD STREET API XHOQ SKARDU":0.2991725557,"GHAZI HOTEL LAKE UPPER KACHURA":0.6614444761,"GRACE LAND HOTEL SKARDU":0.0621873605,"GRAND VIEW HOTEL SKARDU":0.0094215486,"GREEN GUEST HOUSE":-0.0803764982,"HAMALIYA HOTEL SKARDU":0.3943134446,"HARGISA HUT":0.5894501031,"HEAVEN GUEST HOUSE":0.2532096581,"HILTON INTERNATIONAL HOTEL":0.0774527347,"HOTEL 1 SKARDU":0.196706
# ...

# %%
corr_liarliar.loc['SKARDU RESTAURANT'].to_json()
# Out:
# '{"Correlation":1.0,"num of ratings":209.0}'

# %%
xp=(corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head(10)).to_json()
print(xp)
# Out:
# {"Correlation":{"SKARDU RESTAURANT":1.0,"GHAZI HOTEL LAKE UPPER KACHURA":0.6614444761,"HOTEL RIVER VIEW SHIGER":0.6256673212,"CONTINENTAL GUEST HOUSE SKARDU":0.5090213674,"HOTEL DE TRANGO":0.506031615,"FIVE STAR RESTAURANT":0.4060225329,"HOTEL SAFARNGIA RESORT":0.3988174607,"HOTEL HIMALAYA SKARDU":0.3911222143,"SKARDU INN":0.3723780195,"CAPRAFAL GUEST HOUSE":0.3609371261},"num of ratings":{"SKARDU RESTAURANT":209,"GHAZI HOTEL LAKE UPPER KACHURA":136,"HOTEL RIVER VIEW SHIGER":115,"CONTINENTAL GUEST HOUSE SKARDU":121,"HOTEL DE TRANGO":142,"FIVE STAR RESTAURANT":172,"HOTEL SAFARNGIA RESORT":103,"HOTEL HIMALAYA SKARDU":148,"SKARDU INN":441,"CAPRAFAL GUEST HOUSE":197}}

# %%
xp=(corr_liarliar[corr_liarliar['num of ratings']>100].sort_values('Correlation',ascending=False).head(10))
print(xp.iloc[0])
# Out:
# Correlation         1.0
# num of ratings    209.0
# Name: SKARDU RESTAURANT, dtype: float64

# %%
xp.iloc[:,1:2]
xp.to_json()
# Out:
# '{"Correlation":{"SKARDU RESTAURANT":1.0,"GHAZI HOTEL LAKE UPPER KACHURA":0.6614444761,"HOTEL RIVER VIEW SHIGER":0.6256673212,"CONTINENTAL GUEST HOUSE SKARDU":0.5090213674,"HOTEL DE TRANGO":0.506031615,"FIVE STAR RESTAURANT":0.4060225329,"HOTEL SAFARNGIA RESORT":0.3988174607,"HOTEL HIMALAYA SKARDU":0.3911222143,"SKARDU INN":0.3723780195,"CAPRAFAL GUEST HOUSE":0.3609371261},"num of ratings":{"SKARDU RESTAURANT":209,"GHAZI HOTEL LAKE UPPER KACHURA":136,"HOTEL RIVER VIEW SHIGER":115,"CONTINENTAL GUEST HOUSE SKARDU":121,"HOTEL DE TRANGO":142,"FIVE STAR RESTAURANT":172,"HOTEL SAFARNGIA RESORT":103,"HOTEL HIMALAYA SKARDU":148,"SKARDU INN":441,"CAPRAFAL GUEST HOUSE":197}}'

# %%
xp.iloc[:,1:1]
# Out:
# Empty DataFrame
# Columns: []
# Index: [SKARDU RESTAURANT, GHAZI HOTEL LAKE UPPER KACHURA, HOTEL RIVER VIEW SHIGER, CONTINENTAL GUEST HOUSE SKARDU, HOTEL DE TRANGO, FIVE STAR RESTAURANT, HOTEL SAFARNGIA RESORT, HOTEL HIMALAYA SKARDU, SKARDU INN, CAPRAFAL GUEST HOUSE]

# %%
y=xp.iloc[0:1,1:1]
print(y)
# Out:
# Empty DataFrame
# Columns: []
# Index: [SKARDU RESTAURANT]

# %%
xp.head(10)
# Out:
#                                 Correlation  num of ratings
# title
# SKARDU RESTAURANT                  1.000000             209
# GHAZI HOTEL LAKE UPPER KACHURA     0.661444             136
# HOTEL RIVER VIEW SHIGER            0.625667             115
# CONTINENTAL GUEST HOUSE SKARDU     0.509021             121
# HOTEL DE TRANGO                    0.506032             142
# FIVE STAR RESTAURANT               0.406023             172
# HOTEL SAFARNGIA RESORT             0.398817             103
# HOTEL HIMALAYA SKARDU              0.391122             148
# SKARDU INN                         0.372378             441
# CAPRAFAL GUEST HOUSE               0.360937             197

# %%
first = xp.loc[["SKARDU RESTAURANT"], 
                   ["Correlation"]]

# %%
first
# Out:
#                    Correlation
# title
# SKARDU RESTAURANT          1.0

# %%
row2 = xp.iloc [[2, 4]]

# %%
row2
# Out:
#                          Correlation  num of ratings
# title
# HOTEL RIVER VIEW SHIGER     0.625667             115
# HOTEL DE TRANGO             0.506032             142

# %%
xp
# Out:
#                                 Correlation  num of ratings
# title
# SKARDU RESTAURANT                  1.000000             209
# GHAZI HOTEL LAKE UPPER KACHURA     0.661444             136
# HOTEL RIVER VIEW SHIGER            0.625667             115
# CONTINENTAL GUEST HOUSE SKARDU     0.509021             121
# HOTEL DE TRANGO                    0.506032             142
# FIVE STAR RESTAURANT               0.406023             172
# HOTEL SAFARNGIA RESORT             0.398817             103
# HOTEL HIMALAYA SKARDU              0.391122             148
# SKARDU INN                         0.372378             441
# CAPRAFAL GUEST HOUSE               0.360937             197

# %%
xp.reset_index(inplace=True)
xp
# Out:
#                             title  Correlation  num of ratings
# 0               SKARDU RESTAURANT     1.000000             209
# 1  GHAZI HOTEL LAKE UPPER KACHURA     0.661444             136
# 2         HOTEL RIVER VIEW SHIGER     0.625667             115
# 3  CONTINENTAL GUEST HOUSE SKARDU     0.509021             121
# 4                 HOTEL DE TRANGO     0.506032             142
# 5            FIVE STAR RESTAURANT     0.406023             172
# 6          HOTEL SAFARNGIA RESORT     0.398817             103
# 7           HOTEL HIMALAYA SKARDU     0.391122             148
# 8                      SKARDU INN     0.372378             441
# 9            CAPRAFAL GUEST HOUSE     0.360937             197

# %%
xp.columns
xp.iloc[1:,:]
xp.to_json()
# Out:
# '{"title":{"0":"SKARDU RESTAURANT","1":"GHAZI HOTEL LAKE UPPER KACHURA","2":"HOTEL RIVER VIEW SHIGER","3":"CONTINENTAL GUEST HOUSE SKARDU","4":"HOTEL DE TRANGO","5":"FIVE STAR RESTAURANT","6":"HOTEL SAFARNGIA RESORT","7":"HOTEL HIMALAYA SKARDU","8":"SKARDU INN","9":"CAPRAFAL GUEST HOUSE"},"Correlation":{"0":1.0,"1":0.6614444761,"2":0.6256673212,"3":0.5090213674,"4":0.506031615,"5":0.4060225329,"6":0.3988174607,"7":0.3911222143,"8":0.3723780195,"9":0.3609371261},"num of ratings":{"0":209,"1":136,"2":115,"3":121,"4":142,"5":172,"6":103,"7":148,"8":441,"9":197}}'

# %%
xp['title']
# Out:
# 0                 SKARDU RESTAURANT
# 1    GHAZI HOTEL LAKE UPPER KACHURA
# 2           HOTEL RIVER VIEW SHIGER
# 3    CONTINENTAL GUEST HOUSE SKARDU
# 4                   HOTEL DE TRANGO
# 5              FIVE STAR RESTAURANT
# 6            HOTEL SAFARNGIA RESORT
# 7             HOTEL HIMALAYA SKARDU
# 8                        SKARDU INN
# 9              CAPRAFAL GUEST HOUSE
# Name: title, dtype: object

# %%
num=xp.values.tolist()

# %%
num
# Out:
# [['SKARDU RESTAURANT', 1.0, 209],
#  ['GHAZI HOTEL LAKE UPPER KACHURA', 0.6614444760636807, 136],
#  ['HOTEL RIVER VIEW SHIGER', 0.6256673211896344, 115],
#  ['CONTINENTAL GUEST HOUSE SKARDU', 0.509021367445196, 121],
#  ['HOTEL DE TRANGO', 0.5060316150466441, 142],
#  ['FIVE STAR RESTAURANT', 0.40602253293267404, 172],
#  ['HOTEL SAFARNGIA RESORT', 0.39881746068341756, 103],
#  ['HOTEL HIMALAYA SKARDU', 0.39112221434352895, 148],
#  ['SKARDU INN', 0.37237801948167576, 441],
#  ['CAPRAFAL GUEST HOUSE', 0.36093712613162515, 197]]

# %%
xp
# Out:
#                             title  Correlation  num of ratings
# 0               SKARDU RESTAURANT     1.000000             209
# 1  GHAZI HOTEL LAKE UPPER KACHURA     0.661444             136
# 2         HOTEL RIVER VIEW SHIGER     0.625667             115
# 3  CONTINENTAL GUEST HOUSE SKARDU     0.509021             121
# 4                 HOTEL DE TRANGO     0.506032             142
# 5            FIVE STAR RESTAURANT     0.406023             172
# 6          HOTEL SAFARNGIA RESORT     0.398817             103
# 7           HOTEL HIMALAYA SKARDU     0.391122             148
# 8                      SKARDU INN     0.372378             441
# 9            CAPRAFAL GUEST HOUSE     0.360937             197

# %%
z=xp['title'].tolist()

# %%
z
# Out:
# ['SKARDU RESTAURANT',
#  'GHAZI HOTEL LAKE UPPER KACHURA',
#  'HOTEL RIVER VIEW SHIGER',
#  'CONTINENTAL GUEST HOUSE SKARDU',
#  'HOTEL DE TRANGO',
#  'FIVE STAR RESTAURANT',
#  'HOTEL SAFARNGIA RESORT',
#  'HOTEL HIMALAYA SKARDU',
#  'SKARDU INN',
#  'CAPRAFAL GUEST HOUSE']

# %%
z[0]
# Out:
# 'SKARDU RESTAURANT'

# %%
z[1]
# Out:
# 'GHAZI HOTEL LAKE UPPER KACHURA'

# %%
p=pd.merge(hotels_list, hotels_detail, on='item_id')
p.head(5)
# Out:
#    item_id ROOM/NIGHT  STANDRED  NO OF ROOMS  BUDGET  DAYS  \
# 0        1      10000      2300           18  50,000     3
# 1        2      10000      3500           20  50,000     4
# 2        3      19000      5000           15  50,000     2
# 3        4      12000      4500           10  50,000     7
# 4        5      13000      3500           28  50,000     6
#
#                  title          LOCATION  \
# 0     HUNZA VIEW HOTEL  KARIM ABAD HUNZA
# 1  HOTEL HUNZA EMBASSY  KARIM ABAD HUNZA
# 2         DARBAR HOTEL  KARIM ABAD HUNZA
# 3           HAIDER INN     ALIABAD HUNZA
# 4     HUNZA SERENA INN  KARIM ABAD HUNZA
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
# ...

# %%
l=p[['title','BUDGET','STANDRED','CITY','DAYS']]

# %%
l
# Out:
#                           title  BUDGET  STANDRED    CITY  DAYS
# 0              HUNZA VIEW HOTEL  50,000      2300   HUNZA     3
# 1           HOTEL HUNZA EMBASSY  50,000      3500   HUNZA     4
# 2                  DARBAR HOTEL  50,000      5000   HUNZA     2
# 3                    HAIDER INN  50,000      4500   HUNZA     7
# 4              HUNZA SERENA INN  50,000      3500   HUNZA     6
# ...                         ...     ...       ...     ...   ...
# 1439    KARACHII BIRYANI CENTRE  10,000      5000  ASTORE     4
# 1440  NANGA PARBAT HOTEL ASTORE  10,000      4200  ASTORE     7
# 1441      KARACHI NIHARI CENTRE  10,000      3200  ASTORE     6
# 1442               PATHAN HOTEL  10,000      3400  ASTORE     5
# 1443                THE KITCHEN  10,000      4300  ASTORE     4
#
# [1444 rows x 5 columns]

# %%
Num=l[l['title']=='DARBAR HOTEL'].head(1)

# %%
Num
# Out:
#           title  BUDGET  STANDRED   CITY  DAYS
# 2  DARBAR HOTEL  50,000      5000  HUNZA     2

# %%
z
# Out:
# ['SKARDU RESTAURANT',
#  'GHAZI HOTEL LAKE UPPER KACHURA',
#  'HOTEL RIVER VIEW SHIGER',
#  'CONTINENTAL GUEST HOUSE SKARDU',
#  'HOTEL DE TRANGO',
#  'FIVE STAR RESTAURANT',
#  'HOTEL SAFARNGIA RESORT',
#  'HOTEL HIMALAYA SKARDU',
#  'SKARDU INN',
#  'CAPRAFAL GUEST HOUSE']

# %%
Num1=l[l['title']==z[0]].head(1)
Num2=l[l['title']==z[1]].head(1)
Num3=l[l['title']==z[2]].head(1)
Num4=l[l['title']==z[3]].head(1)
Num5=l[l['title']==z[4]].head(1)
Num6=l[l['title']==z[5]].head(1)
Num7=l[l['title']==z[6]].head(1)
Num8=l[l['title']==z[7]].head(1)
Num9=l[l['title']==z[8]].head(1)
Num10=l[l['title']==z[9]].head(1)

# %%
h1=Num1.append(Num2)
h2=h1.append(Num3)
h3=h2.append(Num4)
h4=h3.append(Num5)
h5=h4.append(Num6)
h7=h5.append(Num7)
h8=h7.append(Num8)
h9=h8.append(Num9)

# %%
final_list=pd.merge(xp,h9, on='title')
final_list.head(10)
# Out:
#                             title  Correlation  num of ratings   BUDGET  \
# 0               SKARDU RESTAURANT     1.000000             209   40,000
# 1  GHAZI HOTEL LAKE UPPER KACHURA     0.661444             136   40,000
# 2         HOTEL RIVER VIEW SHIGER     0.625667             115   30,000
# 3  CONTINENTAL GUEST HOUSE SKARDU     0.509021             121   30,000
# 4                 HOTEL DE TRANGO     0.506032             142   25,000
# 5            FIVE STAR RESTAURANT     0.406023             172   40,000
# 6          HOTEL SAFARNGIA RESORT     0.398817             103   30,000
# 7           HOTEL HIMALAYA SKARDU     0.391122             148  400,000
# 8                      SKARDU INN     0.372378             441   40,000
#
#    STANDRED    CITY  DAYS
# 0      2300  SKARDU     4
# 1      4200  SKARDU     7
# 2      2000  SKARDU     7
# 3      2300  SKARDU     5
# 4      2300  SKARDU     3
# 5      3200  SKARDU     6
# 6      4200  SKARDU     4
# 7      3400  SKARDU     4
# ...

# %%
final_list.to_json()
# Out:
# '{"title":{"0":"SKARDU RESTAURANT","1":"GHAZI HOTEL LAKE UPPER KACHURA","2":"HOTEL RIVER VIEW SHIGER","3":"CONTINENTAL GUEST HOUSE SKARDU","4":"HOTEL DE TRANGO"},"Correlation":{"0":1.0,"1":0.6614444761,"2":0.6256673212,"3":0.5090213674,"4":0.506031615},"num of ratings":{"0":209,"1":136,"2":115,"3":121,"4":142},"BUDGET":{"0":"40,000","1":"40,000","2":"30,000","3":"30,000","4":"25,000"},"STANDRED":{"0":2300,"1":4200,"2":2000,"3":2300,"4":2300},"CITY":{"0":"SKARDU","1":"SKARDU","2":"SKARDU","3":"SKARDU","4":"SKARDU"}}'

# %%
a = input("Enter H :")
print(a)
