# %%
import numpy as np
import pandas as pd

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
hotels_detail.head()
# Out:
#    item_id                title          LOCATION  \
# 0        1     HUNZA VIEW HOTEL  KARIM ABAD HUNZA
# 1        2  HOTEL HUNZA EMBASSY  KARIM ABAD HUNZA
# 2        3         DARBAR HOTEL  KARIM ABAD HUNZA
# 3        4           HAIDER INN     ALIABAD HUNZA
# 4        5     HUNZA SERENA INN  KARIM ABAD HUNZA
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES   CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
g =hotels_detail.groupby("CITY")
g

# %%
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
# Out:
# city: ASTORE
#
#
# data:       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1439  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1440  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1441  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1442  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1443  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 566   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# ...                             ...     ...        ...
# 1439  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1440  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1441  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1442  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1443  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                 REVIEWS
# 566   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1439  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1440  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1441  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1442  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1443  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [78 rows x 8 columns]
# city: GILGIT
#
#
# data:       item_id                  title                   LOCATION  \
# 338       339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339       340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340       341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341       342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342       343             PARK HOTEL        AIRPORT ROAD GILGIT
# ...       ...                    ...                        ...
# 1283     1284     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 1284     1285  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 1285     1286         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 1286     1287   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 1287     1288        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                               ROOM TYPE  \
# 338   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1283  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1284  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1285  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1286  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1287  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 338   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ...                             ...     ...        ...
# 1283  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1284  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1285  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1286  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1287  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                 REVIEWS
# 338   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1283  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1284  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1285  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1286  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1287  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [456 rows x 8 columns]
# city: HUNZA
#
#
# data:       item_id                title           LOCATION  \
# 0           1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1           2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2           3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3           4           HAIDER INN      ALIABAD HUNZA
# 4           5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ...       ...                  ...                ...
# 1055     1056   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 1056     1057   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 1057     1058           WHITE ROCK  SHISKAT GOJAL HUN
# 1058     1059    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 1059     1060        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                               ROOM TYPE  \
# 0     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1055  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1056  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1057  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1058  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1059  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES   CITY    PARKING  \
# 0     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ...                             ...    ...        ...
# 1055  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1056  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1057  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1058  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1059  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                 REVIEWS
# 0     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1055  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1056  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1057  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1058  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1059  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [676 rows x 8 columns]
# city: SKARDU
#
#
# data:       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1411  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1412  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1413  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1414  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1415  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 569   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...                             ...     ...        ...
# 1411  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1412  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1413  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1414  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1415  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                 REVIEWS
# 569   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1411  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1412  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1413  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1414  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1415  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [234 rows x 8 columns]

# %%
g.get_group('SKARDU')
# Out:
#       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1411  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1412  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1413  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1414  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1415  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 569   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...                             ...     ...        ...
# 1411  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1412  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1413  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1414  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1415  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                 REVIEWS
# 569   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1411  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1412  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1413  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1414  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1415  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [234 rows x 8 columns]

# %%
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
hotels_list.head(15)
# Out:
#     item_id ROOM/NIGHT  STANDRED  NO OF ROOMS  BUDGET  DAYS
# 0         1      10000      2300           18  50,000     3
# 1         2      10000      3500           20  50,000     4
# 2         3      19000      5000           15  50,000     2
# 3         4      12000      4500           10  50,000     7
# 4         5      13000      3500           28  50,000     6
# 5         6      12000      3000           15  50,000     5
# 6         7      10000      4000           15  50,000     4
# 7         8      13000      9000           15  50,000     4
# 8         9      11000      7000           17  50,000     3
# 9        10      12000      4300           13  50,000     4
# 10       11      13000      3400           12  50,000     5
# 11       12       9000      8500           12  50,000     3
# 12       13       5000      1000           10  50,000     4
# 13       14      20000      3500           20  50,000     7
# 14       15      11000      3000           11  40,000     3

# %%
df = pd.merge(hotels_list,g.get_group('MINIMARG VALLEY ASTORE'),on='item_id')
df.head()
# Out:
#    item_id ROOM/NIGHT  STANDRED  NO OF ROOMS  BUDGET  DAYS  \
# 0      570       9000      3200           12  35,000     3
# 1      571       5000      6000           10  35,000     5
# 2      572      20000      4000           20  35,000     1
# 3      573      11000      5000           11  35,000     3
# 4      574      18000      4300           13  35,000     2
#
#                     title             LOCATION  \
# 0   RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 1            HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 2       SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 3        INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 4  RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
#
#                                            ROOM TYPE  \
# 0  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                  NEAR FACILITIES    CITY    PARKING  \
# 0  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 2  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 3  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 4  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                              REVIEWS
# 0  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...

# %%
l=df[['title','BUDGET','STANDRED','CITY','DAYS']]

# %%
l
# Out:
#                           title  BUDGET  STANDRED    CITY  DAYS
# 0         RAMA GREEN VIEW HOTEL  35,000      3200  SKARDU     3
# 1                  HOTEL SUMMIT  35,000      6000  SKARDU     5
# 2             SUMMIT RESTAURANT  35,000      4000  SKARDU     1
# 3              INDUS VIEW HOTEL  35,000      5000  SKARDU     3
# 4        RAFSAL THE GUEST HOUSE  35,000      4300  SKARDU     2
# ..                          ...     ...       ...     ...   ...
# 229  ROYAL COTTAGE KHAPULO FORT  30,000      2300  SKARDU     3
# 230              CITY INN HOTEL  30,000      5000  SKARDU     4
# 231                BELLA VISTA   30,000      4200  SKARDU     5
# 232             PUNAR INN HOTEL  30,000      3200  SKARDU     3
# 233      ADVENTURE GHAZI RESORT  30,000      3400  SKARDU     4
#
# [234 rows x 5 columns]

# %%
l.columns
#l[l['DAYS']==7
#l.loc[l.title=='PUNAR INN HOTEL']
#l.loc[l.BUDGET=='40,000']
# Out:
# Index(['title', 'BUDGET', 'STANDRED', 'CITY', 'DAYS'], dtype='object')

# %%
#day=7;
#buget=40000;
x=1
y=35000
def get_demo_data(day,buget):
    if day==1 and buget==40000:
        x1=l.loc[l.DAYS==1]
        x1=x1.loc[x1.BUDGET=='40,000']
        return x1
    
    elif day==2 and buget==40000:
        x2=l.loc[l.DAYS==2]
        x2=x2.loc[x2.BUDGET=='40,000']
        return x2
    elif day==3 and buget==40000:
        x3=l.loc[l.DAYS==3]
        x3=x3.loc[x3.BUDGET=='40,000']
        return x3
        #x3
    elif day==4 and buget==40000:
        x4=l.loc[l.DAYS==4]
        x4=x4.loc[x4.BUDGET=='40,000']
        return x4
    #x4
    elif day==5 and buget==40000:
        x5=l.loc[l.DAYS==5]
        x5=x5.loc[x5.BUDGET=='40,000']
        return x5
        #x5
    elif day==6 and buget==40000:
        x6=l.loc[l.DAYS==6]
        x6=x6.loc[x6.BUDGET=='40,000']
        return x6
    
    elif day==7 and buget==40000:
        x7=l.loc[l.DAYS==7]
        x7=x7.loc[x7.BUDGET=='40,000']
        return x7
    elif day==1 and buget==35000:
        y1=l.loc[l.DAYS==1]
        y1=y1.loc[y1.BUDGET=='35,000']
        return y1
    elif day==2 and buget==35000: 
        y2=l.loc[l.DAYS==2]
        y2=y2.loc[y2.BUDGET=='35,000']
        return y2
    elif day==3 and buget==35000:
        y3=l.loc[l.DAYS==3]
        y3=y3.loc[y3.BUDGET=='35,000']
        return y3
    elif day==4 and buget==35000:
        y4=l.loc[l.DAYS==4]
        y4=y4.loc[y4.BUDGET=='35,000']
        return y4
    elif day==5 and buget==35000:
        y5=l.loc[l.DAYS==5]
        y5=y5.loc[y5.BUDGET=='35,000']
        return y5
    elif day==6 and buget==35000:
        y6=l.loc[l.DAYS==6]
        y6=y6.loc[y6.BUDGET=='35,000']
        return y6
    elif day==7 and buget==35000:
        y7=l.loc[l.DAYS==7]
        y7=y7.loc[y7.BUDGET=='35,000']
        return y7
    elif day==1 and buget==30000:
        z1=l.loc[l.DAYS==1]
        z1=z1.loc[z1.BUDGET=='30,000']
        return z1
    elif day==2 and buget==30000:   
        z2=l.loc[l.DAYS==2]
        z2=z2.loc[z2.BUDGET=='30,000']
        return z2
    elif day==3 and buget==30000:
        z3=l.loc[l.DAYS==3]
        z3=z3.loc[z3.BUDGET=='30,000']
        return z3
    elif day==4 and buget==30000:
        z4=l.loc[l.DAYS==4]
        z4=z4.loc[z4.BUDGET=='30,000']
        return z4
    elif day==5 and buget==30000:
        z5=l.loc[l.DAYS==5]
        z5=z5.loc[z5.BUDGET=='30,000']
        return z5
    elif day==6 and buget==30000:
        z6=l.loc[l.DAYS==6]
        z6=z6.loc[z6.BUDGET=='30,000']
        return z6
    elif day==7 and buget==30000:
        z7=l.loc[l.DAYS==7]
        z7=z7.loc[z7.BUDGET=='30,000']
        return z7
    elif day==1 and buget==25000:   
        y_1=l.loc[l.DAYS==1]
        y_1=y_1.loc[y_1.BUDGET=='25,000']
        return y_1
    elif day==2 and buget==25000:
        y_2=l.loc[l.DAYS==2]
        y_2=y_2.loc[y_2.BUDGET=='25,000']
        return y_2
    elif day==3 and buget==25000:
        y_3=l.loc[l.DAYS==3]
        y_3=y_3.loc[y_3.BUDGET=='25,000']
        return y_3
    elif day==4 and buget==25000:
        y_4=l.loc[l.DAYS==4]
        y_4=y4.loc[y_4.BUDGET=='25,000']
        return y_4
    elif day==5 and buget==25000:
        y_5=l.loc[l.DAYS==5]
        y_5=y5.loc[y_5.BUDGET=='25,000']
        return y_5
    elif day==6 and buget==25000:
        y_6=l.loc[l.DAYS==6]
        y_6=y_6.loc[y_6.BUDGET=='25,000']
        return y_6
    elif day==7 and buget==25000:
        y_7=l.loc[l.DAYS==7]
        y_7=y_7.loc[y_7.BUDGET=='25,000']
        return y_7
    elif day==1 and buget==20000:
        x_1=l.loc[l.DAYS==1]
        x_1=x_1.loc[x_1.BUDGET=='20,000']
        return x_1
    elif day==2 and buget==20000:
        x_2=l.loc[l.DAYS==2]
        x_2=x_2.loc[x_2.BUDGET=='20,000']
        return x_2
    elif day==3 and buget==20000:
        x_3=l.loc[l.DAYS==3]
        x_3=x_3.loc[x_3.BUDGET=='20,000']
        return x_3
    elif day==4 and buget==20000:
        x_4=l.loc[l.DAYS==4]
        x_4=x_4.loc[x_4.BUDGET=='20,000']
        return x_4
    elif day==5 and buget==20000:
        x_5=l.loc[l.DAYS==5]
        x_5=x_5.loc[x_5.BUDGET=='20,000']
        return x_5
    elif day==6 and buget==20000:
        x_6=l.loc[l.DAYS==6]
        x_6=x_6.loc[x_6.BUDGET=='20,000']
        return x_6
    elif day==7 and buget==20000:
        x_7=l.loc[l.DAYS==7]
        x_7=x_7.loc[x_7.BUDGET=='20,000']
        return x_7
    elif day==1 and buget==15000:
        z_1=l.loc[l.DAYS==1]
        z_1=z_1.loc[z_1.BUDGET=='15,000']
        return z_1
    elif day==2 and buget==15000:
        z_2=l.loc[l.DAYS==2]
        z_2=z_2.loc[z_2.BUDGET=='15,000']
        return z_2
    elif day==3 and buget==15000:
        z_3=l.loc[l.DAYS==3]
        z_3=z3.loc[z_3.BUDGET=='15,000']
        return z_3
    elif day==4 and buget==15000:
        z_4=l.loc[l.DAYS==4]
        z_4=z_4.loc[z_4.BUDGET=='15,000']
        return z_4
    elif day==5 and buget==15000:
        z_5=l.loc[l.DAYS==5]
        z_5=z5.loc[z5.BUDGET=='15,000']
        return z_5
    elif day==6 and buget==15000:
        z_6=l.loc[l.DAYS==6]
        z_6=z_6.loc[z_6.BUDGET=='15,000']
        return z_6
    elif day==7 and buget==15000:
        z_7=l.loc[l.DAYS==7]
        z_7=z_7.loc[z_7.BUDGET=='15,000']
        return z_7
    if day==1 and buget==10000:
        x1=l.loc[l.DAYS==1]
        x1=x1.loc[x1.BUDGET=='10,000']
        return x1
    
    elif day==2 and buget==10000:
        x2=l.loc[l.DAYS==2]
        x2=x2.loc[x2.BUDGET=='10,000']
        return x2
    elif day==3 and buget==10000:
        x3=l.loc[l.DAYS==3]
        x3=x3.loc[x3.BUDGET=='10,000']
        return x3
        #x3
    elif day==4 and buget==10000:
        x4=l.loc[l.DAYS==4]
        x4=x4.loc[x4.BUDGET=='10,000']
        return x4
    #x4
    elif day==5 and buget==10000:
        x5=l.loc[l.DAYS==5]
        x5=x5.loc[x5.BUDGET=='10,000']
        return x5
        #x5
    elif day==6 and buget==10000:
        x6=l.loc[l.DAYS==6]
        x6=x6.loc[x6.BUDGET=='10,000']
        return x6
    
    elif day==7 and buget==10000:
        x7=l.loc[l.DAYS==7]
        x7=x7.loc[x7.BUDGET=='10,000']
        return x7
    else:
        return"Please Enter Correct value"
    
get_demo_data(x,y)
# Out:
#                title  BUDGET  STANDRED    CITY  DAYS
# 2  SUMMIT RESTAURANT  35,000      4000  SKARDU     1

# %%
y1=l.loc[l.DAYS==1]
y1=y1.loc[y1.BUDGET=='35,000']
#y1
y2=l.loc[l.DAYS==2]
y2=y2.loc[y2.BUDGET=='35,000']
#x2
y3=l.loc[l.DAYS==3]
y3=y3.loc[y3.BUDGET=='35,000']
#x3
y4=l.loc[l.DAYS==4]
y4=y4.loc[y4.BUDGET=='35,000']
#x4
y5=l.loc[l.DAYS==5]
y5=y5.loc[y5.BUDGET=='35,000']
#x5
y6=l.loc[l.DAYS==6]
y6=y6.loc[y6.BUDGET=='35,000']
#x6
y7=l.loc[l.DAYS==7]
y7=y7.loc[y7.BUDGET=='35,000']

# %%
z1=l.loc[l.DAYS==1]
z1=z1.loc[z1.BUDGET=='30,000']
#y1
z2=l.loc[l.DAYS==2]
z2=z2.loc[z2.BUDGET=='30,000']
#x2
z3=l.loc[l.DAYS==3]
z3=z3.loc[z3.BUDGET=='30,000']
#x3
z4=l.loc[l.DAYS==4]
z4=z4.loc[z4.BUDGET=='30,000']
#x4
z5=l.loc[l.DAYS==5]
z5=z5.loc[z5.BUDGET=='30,000']
#x5
z6=l.loc[l.DAYS==6]
z6=z6.loc[z6.BUDGET=='30,000']
#x6
z7=l.loc[l.DAYS==7]
z7=z7.loc[z7.BUDGET=='30,000']
#z6

# %%
y_1=l.loc[l.DAYS==1]
y_1=y_1.loc[y_1.BUDGET=='25,000']
#y1
y_2=l.loc[l.DAYS==2]
y_2=y_2.loc[y_2.BUDGET=='25,000']
#x2
y_3=l.loc[l.DAYS==3]
y_3=y_3.loc[y_3.BUDGET=='25,000']
#x3
y_4=l.loc[l.DAYS==4]
y_4=y4.loc[y_4.BUDGET=='25,000']
#x4
y_5=l.loc[l.DAYS==5]
y_5=y5.loc[y_5.BUDGET=='25,000']
#x5
y_6=l.loc[l.DAYS==6]
y_6=y_6.loc[y_6.BUDGET=='25,000']
#x6
y_7=l.loc[l.DAYS==7]
y_7=y_7.loc[y_7.BUDGET=='25,000']
y_6
# Out:
#           title  BUDGET  STANDRED    CITY  DAYS
# 24  INDUS MOTEL  25,000      5000  SKARDU     6

# %%
x_1=l.loc[l.DAYS==1]
x_1=x_1.loc[x_1.BUDGET=='20,000']
#x1
x_2=l.loc[l.DAYS==2]
x_2=x_2.loc[x_2.BUDGET=='20,000']
#x2
x_3=l.loc[l.DAYS==3]
x_3=x_3.loc[x_3.BUDGET=='20,000']
#x3
x_4=l.loc[l.DAYS==4]
x_4=x_4.loc[x_4.BUDGET=='20,000']
#x4
x_5=l.loc[l.DAYS==5]
x_5=x_5.loc[x_5.BUDGET=='20,000']
#x5
x_6=l.loc[l.DAYS==6]
x_6=x_6.loc[x_6.BUDGET=='20,000']
#x6
x_7=l.loc[l.DAYS==7]
x_7=x_7.loc[x_7.BUDGET=='20,000']
x_6
# Out:
#                  title  BUDGET  STANDRED    CITY  DAYS
# 41  HOTEL DEWAN-E-KHAS  20,000      4200  SKARDU     6

# %%
z_1=l.loc[l.DAYS==1]
z_1=z_1.loc[z_1.BUDGET=='15,000']
#y1
z_2=l.loc[l.DAYS==2]
z_2=z_2.loc[z_2.BUDGET=='15,000']
#x2
z_3=l.loc[l.DAYS==3]
z_3=z3.loc[z_3.BUDGET=='15,000']
#x3
z_4=l.loc[l.DAYS==4]
z_4=z_4.loc[z_4.BUDGET=='15,000']
#x4
z_5=l.loc[l.DAYS==5]
z_5=z5.loc[z5.BUDGET=='15,000']
#x5
z_6=l.loc[l.DAYS==6]
z_6=z_6.loc[z_6.BUDGET=='15,000']
#x6
z_7=l.loc[l.DAYS==7]
z_7=z_7.loc[z_7.BUDGET=='15,000']
z_7
# Out:
#                      title  BUDGET  STANDRED    CITY  DAYS
# 49  RAFSAL THE GUEST HOUSE  15,000      4200  SKARDU     7

# %%
def return_multiple_values():
    return (1, 2)
x=return_multiple_values
print(x)
# Out:
# <function return_multiple_values at 0x060F6780>

# %%
global x
global y
global z
def return_multiple_values():
    x=1
    y=8
    z=9
    return (x, y, z)
    a=return_multiple_values()
print(a[0])
print(a[1])
print(a[2])
a1=a[0]
b1=a[1]
c1=a[2]
print(a1)
print(b1)
print(c1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-01e92db35f36> in <module>
#       8     return (x, y, z)
#       9     a=return_multiple_values()
# ---> 10 print(a[0])
#      11 print(a[1])
#      12 print(a[2])
#
# NameError: name 'a' is not defined

# %%
print(a[0])
print(a[1])
print(a[2])
a1=a[0]
b1=a[1]
c1=a[2]
print(a1)
print(b1)
print(c1)

# %%
global x
global y

def login():
    print("A")
    x=1
    y=15000
    z='{} {}'.format(x, y)
    return z 
ds=login()
#print(ds)
#print(type(ds))
#res = tuple(map(int, ds.split(' ')))
#print(res)
#print(res[0])
#print(res[1])
print(ds)

# %%
test_str = "1, -5, 4, 6, aziz"
  
# printing original string  
print("The original string : " + str(test_str)) 
  
# Convert String to Tuple 
# using map() + tuple() + int + split() 
res = tuple(map(int, test_str.split(', '))) 
  
# printing result 
print("Tuple after getting conversion from String : " + str(res))

# %%
def convertTuple(tup):
    str =  ''.join(tup)
    return str
  
# Driver code
tuple = ('1', '2', 'e', 'k', 's')
str = convertTuple(tuple)
print(str)
# Out:
# 12eks

# %%
values = input("Input some comma seprated numbers : ")
list = values.split(",")
tuple = tuple(list)
print('List : ',list)
print('Tuple : ',tuple)
# Out:
# Input some comma seprated numbers :
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6030b101377c> in <module>
#       1 values = input("Input some comma seprated numbers : ")
#       2 list = values.split(",")
# ----> 3 tuple = tuple(list)
#       4 print('List : ',list)
#       5 print('Tuple : ',tuple)
#
# TypeError: 'tuple' object is not callable

# %%
inpstr = input ("Enter comma-separated string: ")
print ("Input string given by user: ", inpstr)
tuple = tuple(inpstr.split (","))
print("Tuple containing comma-separated string is: ",tuple)
# Out:
# Enter comma-separated string:
# Input string given by user:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f8a565fac208> in <module>
#       1 inpstr = input ("Enter comma-separated string: ")
#       2 print ("Input string given by user: ", inpstr)
# ----> 3 tuple = tuple(inpstr.split (","))
#       4 print("Tuple containing comma-separated string is: ",tuple)
#
# TypeError: 'tuple' object is not callable

# %%
text = 'The quick brown fox jumps over the lazy dog'
  
# Split the text wherever there's a space.
words = text.split()
print(words[0])
# Out:
# The

# %%
# List initialization
input = [11500]
  
# Using map
output = list(map(int, str(input[])))
  
# Printing output
print(output)
# Out:
#   File "<ipython-input-7-b5739c4cf38e>", line 5
#     output = list(map(int, str(input[])))
#                                      ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-9-6c9186cfdf8a>", line 2
#     print tuple(a)
#               ^
# SyntaxError: invalid syntax

# %%
import ast

def parse_tuple(string):
    try:
        s = ast.literal_eval(str(string))
        if type(s) == tuple:
            return s
        return
    except:
        return
parse_tuple('("A","B","C",)')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-51eec42130c6> in <module>
#       1 s="jack"
#       2
# ----> 3 tup=tuple(s.split(" "))
#
# TypeError: 'tuple' object is not callable

# %%
        hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
        g =hotels_detail.groupby("CITY")
        g.get_group('HUNZA')
        g.get_group('ASTORE')
        g.get_group('GILGIT')
        g.get_group('SKARDU')
        hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
        column_names = ['user_id', 'item_id', 'rating', 'timestamp']
        df = pd.read_csv('u.data', sep='\t', names=column_names)
        df1 = pd.read_csv('u.data', sep='\t', names=column_names)
        df2 = pd.read_csv('u.data', sep='\t', names=column_names)
        df3 = pd.read_csv('u.data', sep='\t', names=column_names)
        df = pd.merge(df,g.get_group('SKARDU'),on='item_id') 
        df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
        df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
        df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
        df1.groupby('title')['rating'].mean().sort_values(ascending=False).head() 
        df1.groupby('title')['rating'].count().sort_values(ascending=False).head()
        ratings = pd.DataFrame(df1.groupby('title')['rating'].mean())
        ratings['num of ratings'] = pd.DataFrame(df1.groupby('title')['rating'].count())
        hotelmat = df1.pivot_table(index='user_id',columns='title',values='rating')
        ratings.sort_values('num of ratings',ascending=False).head(10)
        star_user_ratings = hotelmat["RAMA GREEN VIEW HOTEL"]
        standard_user_ratings = hotelmat["RAMA GREEN VIEW HOTEL"]
        similar_to_star = hotelmat.corrwith(star_user_ratings)
        similar_to_standard = hotelmat.corrwith(standard_user_ratings)
        corr_star = pd.DataFrame(similar_to_star,columns=['Correlation'])
        corr_star.dropna(inplace=True)
        corr_star.sort_values('Correlation',ascending=False).head(10)
        corr_star = corr_star.join(ratings['num of ratings'])
        corr_star.head()
        corr_star[corr_star['num of ratings']>100].sort_values('Correlation',ascending=False).head()
        corr_standard = pd.DataFrame(similar_to_standard,columns=['Correlation'])
        corr_standard.dropna(inplace=True)
        corr_standard = corr_standard.join(ratings['num of ratings'])
        corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head()
        print(corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head())
        xp=(corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head())
        xp.reset_index(inplace=True)
        b=xp.iloc[:,:]
        z=b.to_json()
        print(z)
        print("Get it")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RAMA GREEN VIEW HOTEL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-98a50a1f988f> in <module>
#      21 hotelmat = df1.pivot_table(index='user_id',columns='title',values='rating')
#      22 ratings.sort_values('num of ratings',ascending=False).head(10)
# ---> 23 star_user_ratings = hotelmat["RAMA GREEN VIEW HOTEL"]
#      24 standard_user_ratings = hotelmat["RAMA GREEN VIEW HOTEL"]
#      25 similar_to_star = hotelmat.corrwith(star_user_ratings)
#
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# c:\users\nova data\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'RAMA GREEN VIEW HOTEL'

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
hotels_detail.head()
hotels_detail.shape
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA')
g.get_group('ASTORE')
g.get_group('GILGIT')
g.get_group('SKARDU')
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
hotels_list.head(15)
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df.head(5)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
ratings.head()
hotelmat = df.pivot_table(index='user_id',columns='title',values='rating')
hotelmat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_user_ratings = hotelmat['SKARDU INN']
standard_user_ratings = hotelmat['SKARDU RESTAURANT']
star_user_ratings.head()
similar_to_star = hotelmat.corrwith(star_user_ratings)
similar_to_standard = hotelmat.corrwith(standard_user_ratings)
corr_star = pd.DataFrame(similar_to_star,columns=['Correlation'])
corr_star.dropna(inplace=True)
corr_star.head()
corr_star.sort_values('Correlation',ascending=False).head(10)
corr_star = corr_star.join(ratings['num of ratings'])
corr_star.head()
corr_star[corr_star['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_standard = pd.DataFrame(similar_to_standard,columns=['Correlation'])
corr_standard.dropna(inplace=True)
corr_standard = corr_standard.join(ratings['num of ratings'])
xp=(corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1439  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1440  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1441  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1442  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1443  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 566   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# ...                             ...     ...        ...
# 1439  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1440  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1441  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1442  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1443  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                 REVIEWS
# 566   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1439  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1440  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1441  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1442  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1443  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [78 rows x 8 columns]
# city: GILGIT
#
#
# data:       item_id                  title                   LOCATION  \
# 338       339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339       340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340       341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341       342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342       343             PARK HOTEL        AIRPORT ROAD GILGIT
# ...       ...                    ...                        ...
# 1283     1284     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 1284     1285  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 1285     1286         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 1286     1287   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 1287     1288        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                               ROOM TYPE  \
# 338   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1283  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1284  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1285  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1286  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1287  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 338   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ...                             ...     ...        ...
# 1283  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1284  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1285  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1286  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1287  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                 REVIEWS
# 338   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1283  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1284  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1285  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1286  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1287  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [456 rows x 8 columns]
# city: HUNZA
#
#
# data:       item_id                title           LOCATION  \
# 0           1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1           2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2           3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3           4           HAIDER INN      ALIABAD HUNZA
# 4           5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ...       ...                  ...                ...
# 1055     1056   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 1056     1057   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 1057     1058           WHITE ROCK  SHISKAT GOJAL HUN
# 1058     1059    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 1059     1060        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                               ROOM TYPE  \
# 0     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1055  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1056  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1057  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1058  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1059  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES   CITY    PARKING  \
# 0     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ...                             ...    ...        ...
# 1055  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1056  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1057  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1058  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1059  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                 REVIEWS
# 0     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1055  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1056  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1057  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1058  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1059  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# [676 rows x 8 columns]
# city: SKARDU
#
#
# data:       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1411  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1412  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1413  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1414  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1415  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 569   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...                             ...     ...        ...
# 1411  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1412  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1413  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1414  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1415  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                 REVIEWS
# 569   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1411  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1412  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1413  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1414  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1415  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [234 rows x 8 columns]
# '{"title":{"0":"SKARDU RESTAURANT","1":"GHAZI HOTEL LAKE UPPER KACHURA","2":"HOTEL RIVER VIEW SHIGER","3":"CONTINENTAL GUEST HOUSE SKARDU","4":"HOTEL DE TRANGO"},"Correlation":{"0":1.0,"1":0.6614444761,"2":0.6256673212,"3":0.5090213674,"4":0.506031615},"num of ratings":{"0":209,"1":136,"2":115,"3":121,"4":142}}'

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
hotels_detail.head()
hotels_detail.shape
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA')
g.get_group('ASTORE')
g.get_group('GILGIT')
g.get_group('SKARDU')
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
hotels_list.head(15)
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df.head(5)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df1.groupby('title')['rating'].mean().sort_values(ascending=False).head()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
df1.groupby('title')['rating'].mean().sort_values(ascending=False).head()
df1.groupby('title')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df1.groupby('title')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df1.groupby('title')['rating'].count())
ratings.head()
ratings.head()
hotelmat = df1.pivot_table(index='user_id',columns='title',values='rating')
hotelmat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_user_ratings = hotelmat['MANSERA HOTEL']
standard_user_ratings = hotelmat['AL -BARKAT HOTEL']
star_user_ratings.head()
similar_to_star = hotelmat.corrwith(star_user_ratings)
similar_to_standard = hotelmat.corrwith(standard_user_ratings)
corr_star = pd.DataFrame(similar_to_star,columns=['Correlation'])
corr_star.dropna(inplace=True)
corr_star.head()
corr_star.sort_values('Correlation',ascending=False).head(10)
corr_star = corr_star.join(ratings['num of ratings'])
corr_star.head()
corr_star[corr_star['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_standard = pd.DataFrame(similar_to_standard,columns=['Correlation'])
corr_standard.dropna(inplace=True)
corr_standard = corr_standard.join(ratings['num of ratings'])
corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1439  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1440  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1441  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1442  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1443  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 566   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# ...                             ...     ...        ...
# 1439  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1440  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1441  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1442  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1443  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                 REVIEWS
# 566   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1439  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1440  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1441  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1442  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1443  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [78 rows x 8 columns]
# city: GILGIT
#
#
# data:       item_id                  title                   LOCATION  \
# 338       339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339       340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340       341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341       342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342       343             PARK HOTEL        AIRPORT ROAD GILGIT
# ...       ...                    ...                        ...
# 1283     1284     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 1284     1285  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 1285     1286         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 1286     1287   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 1287     1288        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                               ROOM TYPE  \
# 338   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1283  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1284  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1285  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1286  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1287  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 338   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ...                             ...     ...        ...
# 1283  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1284  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1285  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1286  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1287  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                 REVIEWS
# 338   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1283  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1284  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1285  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1286  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1287  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [456 rows x 8 columns]
# city: HUNZA
#
#
# data:       item_id                title           LOCATION  \
# 0           1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1           2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2           3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3           4           HAIDER INN      ALIABAD HUNZA
# 4           5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ...       ...                  ...                ...
# 1055     1056   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 1056     1057   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 1057     1058           WHITE ROCK  SHISKAT GOJAL HUN
# 1058     1059    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 1059     1060        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                               ROOM TYPE  \
# 0     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1055  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1056  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1057  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1058  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1059  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES   CITY    PARKING  \
# 0     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ...                             ...    ...        ...
# 1055  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1056  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1057  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1058  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1059  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                 REVIEWS
# 0     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1055  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1056  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1057  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1058  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1059  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [676 rows x 8 columns]
# city: SKARDU
#
#
# data:       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1411  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1412  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1413  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1414  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1415  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 569   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...                             ...     ...        ...
# 1411  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1412  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1413  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1414  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1415  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                 REVIEWS
# 569   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1411  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1412  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1413  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1414  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1415  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [234 rows x 8 columns]
# '{"title":{"0":"AL -BARKAT HOTEL","1":"DUMANI HOTEL","2":"VISTA HOTEL","3":"MOUNTAIN INN HUNZA","4":"AL-MEHMOOD HOTEL"},"Correlation":{"0":1.0,"1":0.4264463407,"2":0.4104546215,"3":0.3910953845,"4":0.3868790001},"num of ratings":{"0":338,"1":263,"2":244,"3":112,"4":231}}'

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
hotels_detail.head()
hotels_detail.shape
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA')
g.get_group('ASTORE')
g.get_group('GILGIT')
g.get_group('SKARDU')
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
hotels_list.head(15)
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df.head(5)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df1.groupby('title')['rating'].mean().sort_values(ascending=False).head()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
df2.groupby('title')['rating'].mean().sort_values(ascending=False).head()
df2.groupby('title')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df2.groupby('title')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df2.groupby('title')['rating'].count())
ratings.head()
ratings.head()
hotelmat = df2.pivot_table(index='user_id',columns='title',values='rating')
hotelmat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_user_ratings = hotelmat['RAMA MIDWAY GUEST HOSUE']
standard_user_ratings = hotelmat['KAMRAN HOTEL']
star_user_ratings.head()
similar_to_star = hotelmat.corrwith(star_user_ratings)
similar_to_standard = hotelmat.corrwith(standard_user_ratings)
corr_star = pd.DataFrame(similar_to_star,columns=['Correlation'])
corr_star.dropna(inplace=True)
corr_star.head()
corr_star.sort_values('Correlation',ascending=False).head(10)
corr_star = corr_star.join(ratings['num of ratings'])
corr_star.head()
corr_star[corr_star['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_standard = pd.DataFrame(similar_to_standard,columns=['Correlation'])
corr_standard.dropna(inplace=True)
corr_standard = corr_standard.join(ratings['num of ratings'])
corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1439  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1440  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1441  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1442  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1443  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 566   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# ...                             ...     ...        ...
# 1439  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1440  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1441  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1442  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1443  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                 REVIEWS
# 566   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1439  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1440  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1441  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1442  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1443  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [78 rows x 8 columns]
# city: GILGIT
#
#
# data:       item_id                  title                   LOCATION  \
# 338       339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339       340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340       341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341       342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342       343             PARK HOTEL        AIRPORT ROAD GILGIT
# ...       ...                    ...                        ...
# 1283     1284     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 1284     1285  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 1285     1286         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 1286     1287   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 1287     1288        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                               ROOM TYPE  \
# 338   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1283  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1284  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1285  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1286  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1287  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 338   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ...                             ...     ...        ...
# 1283  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1284  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1285  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1286  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1287  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                 REVIEWS
# 338   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1283  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1284  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1285  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1286  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1287  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [456 rows x 8 columns]
# city: HUNZA
#
#
# data:       item_id                title           LOCATION  \
# 0           1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1           2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2           3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3           4           HAIDER INN      ALIABAD HUNZA
# 4           5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ...       ...                  ...                ...
# 1055     1056   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 1056     1057   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 1057     1058           WHITE ROCK  SHISKAT GOJAL HUN
# 1058     1059    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 1059     1060        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                               ROOM TYPE  \
# 0     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1055  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1056  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1057  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1058  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1059  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES   CITY    PARKING  \
# 0     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ...                             ...    ...        ...
# 1055  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1056  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1057  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1058  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1059  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                 REVIEWS
# 0     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1055  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1056  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1057  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1058  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1059  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [676 rows x 8 columns]
# city: SKARDU
#
#
# data:       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1411  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1412  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1413  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1414  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1415  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 569   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...                             ...     ...        ...
# 1411  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1412  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1413  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1414  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1415  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                 REVIEWS
# 569   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1411  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1412  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1413  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1414  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1415  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [234 rows x 8 columns]
# '{"title":{"0":"KAMRAN HOTEL","1":"HOTEL MOUNTAIN LOGOON ","2":"BULAN HOTEL","3":"AL-IMRAN HOTEL","4":"RAMA MIDWAY GUEST HOSUE"},"Correlation":{"0":1.0,"1":0.414119988,"2":0.2800766081,"3":0.1917713184,"4":0.1743015232},"num of ratings":{"0":359,"1":107,"2":113,"3":142,"4":179}}'

# %%
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\desktop.csv")
hotels_detail.head()
hotels_detail.shape
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA')
g.get_group('ASTORE')
g.get_group('GILGIT')
g.get_group('SKARDU')
hotels_list = pd.read_csv("C:\\Users\\Nova Data\\Desktop\H_list.csv")
hotels_list.head(15)
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df.head(5)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA'),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df3.groupby('title')['rating'].mean().sort_values(ascending=False).head()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
df3.groupby('title')['rating'].mean().sort_values(ascending=False).head()
df3.groupby('title')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df3.groupby('title')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df3.groupby('title')['rating'].count())
ratings.head()
ratings.head()
hotelmat = df3.pivot_table(index='user_id',columns='title',values='rating')
hotelmat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_user_ratings = hotelmat['YASIN HOLIDAY HOTEL GILGIT']
standard_user_ratings = hotelmat['GILGITI FOOD YARD']
star_user_ratings.head()
similar_to_star = hotelmat.corrwith(star_user_ratings)
similar_to_standard = hotelmat.corrwith(standard_user_ratings)
corr_star = pd.DataFrame(similar_to_star,columns=['Correlation'])
corr_star.dropna(inplace=True)
corr_star.head()
corr_star.sort_values('Correlation',ascending=False).head(10)
corr_star = corr_star.join(ratings['num of ratings'])
corr_star.head()
corr_star[corr_star['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_standard = pd.DataFrame(similar_to_standard,columns=['Correlation'])
corr_standard.dropna(inplace=True)
corr_standard = corr_standard.join(ratings['num of ratings'])
corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_standard[corr_standard['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:       item_id                      title                   LOCATION  \
# 566       567     HOTEL MOUNTAIN LOGOON       NEAR SHANGRILA RESORT
# 567       568               KAMRAN HOTEL           RAMA ROAD ASTORE
# 568       569          KAMRAN RESTAURANT           RAMA ROAD ASTORE
# 582       583    RAMA MIDWAY GUEST HOSUE           RAMA ROAD ASTORE
# 583       584    GRACE LAND HOTEL SKARDU               PATAWAL ROAD
# ...       ...                        ...                        ...
# 1439     1440    KARACHII BIRYANI CENTRE             GORIKOT ASTORE
# 1440     1441  NANGA PARBAT HOTEL ASTORE                     ASTORE
# 1441     1442      KARACHI NIHARI CENTRE              EDIGAH ASTORE
# 1442     1443               PATHAN HOTEL                     ASTORE
# 1443     1444                THE KITCHEN  ASTORE VALLEY ROAD ASTORE
#
#                                               ROOM TYPE  \
# 566   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 567   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 568   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 582   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 583   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1439  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1440  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1441  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1442  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1443  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 566   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 567   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 568   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 582   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 583   HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# ...                             ...     ...        ...
# 1439  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1440  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1441  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1442  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
# 1443  HOSPITAL,MARKET,PICNIC POINTS  ASTORE  AVAILABLE
#
#                                                 REVIEWS
# 566   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 567   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 568   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 582   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 583   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1439  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1440  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1441  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1442  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1443  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [78 rows x 8 columns]
# city: GILGIT
#
#
# data:       item_id                  title                   LOCATION  \
# 338       339    GILGIT SERENA HOTEL             JUTIYAL GILGIT
# 339       340      PTDC GILGIT MOTEL          BABAR ROAD GILGIT
# 340       341       RIVERDALE RESORT          BASEEN RCC GILGIT
# 341       342         MADINA HOTEL 2          BABAR ROAD GILGIT
# 342       343             PARK HOTEL        AIRPORT ROAD GILGIT
# ...       ...                    ...                        ...
# 1283     1284     HOTEL DEWAN-E-KHAS  DEWANE-E-KHAS ROAD SKARDU
# 1284     1285  HOTEL SNOWLAND PALACE        HAMEED GARGH SKARDU
# 1285     1286         HOTEL 1 SKARDU        AIRPORT ROAD SKARDU
# 1286     1287   HOTEL MOUNTAIN LODGE        SATPARA ROAD SKARDU
# 1287     1288        HOTEL MASHABRUM        COLLOGE ROAD SKARDU
#
#                                               ROOM TYPE  \
# 338   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 339   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 340   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 341   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 342   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1283  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1284  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1285  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1286  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1287  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 338   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 339   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 340   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 341   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 342   HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# ...                             ...     ...        ...
# 1283  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1284  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1285  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1286  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
# 1287  HOSPITAL,MARKET,PICNIC POINTS  GILGIT  AVAILABLE
#
#                                                 REVIEWS
# 338   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 339   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 340   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 341   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 342   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1283  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1284  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1285  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1286  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1287  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [456 rows x 8 columns]
# city: HUNZA
#
#
# data:       item_id                title           LOCATION  \
# 0           1     HUNZA VIEW HOTEL   KARIM ABAD HUNZA
# 1           2  HOTEL HUNZA EMBASSY   KARIM ABAD HUNZA
# 2           3         DARBAR HOTEL   KARIM ABAD HUNZA
# 3           4           HAIDER INN      ALIABAD HUNZA
# 4           5     HUNZA SERENA INN   KARIM ABAD HUNZA
# ...       ...                  ...                ...
# 1055     1056   PEARLS HUTS RESORT  SHISKAT GOJAL HUN
# 1056     1057   PERCH  GUEST HOUSE  SHISKAT GOJAL HUN
# 1057     1058           WHITE ROCK  SHISKAT GOJAL HUN
# 1058     1059    GULMIT FARM HOUSE  SHISKAT GOJAL HUN
# 1059     1060        MINTIKA LODGE  SHISKAT GOJAL HUN
#
#                                               ROOM TYPE  \
# 0     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 2     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 3     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 4     TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1055  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1056  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1057  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1058  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1059  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES   CITY    PARKING  \
# 0     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 2     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 3     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 4     HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# ...                             ...    ...        ...
# 1055  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1056  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1057  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1058  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
# 1059  HOSPITAL,MARKET,PICNIC POINTS  HUNZA  AVAILABLE
#
#                                                 REVIEWS
# 0     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 2     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 3     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 4     EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1055  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1056  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1057  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1058  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1059  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [676 rows x 8 columns]
# city: SKARDU
#
#
# data:       item_id                       title             LOCATION  \
# 569       570       RAMA GREEN VIEW HOTEL     RAMA ROAD ASTORE
# 570       571                HOTEL SUMMIT  AIRPORT ROAD SKARDU
# 571       572           SUMMIT RESTAURANT  AIRPORT ROAD SKARDU
# 572       573            INDUS VIEW HOTEL  AIRPORT ROAD SKARDU
# 573       574      RAFSAL THE GUEST HOUSE  AIRPORT ROAD SKARDU
# ...       ...                         ...                  ...
# 1411     1412  ROYAL COTTAGE KHAPULO FORT               SKARDU
# 1412     1413              CITY INN HOTEL               SKARDU
# 1413     1414                BELLA VISTA                SKARDU
# 1414     1415             PUNAR INN HOTEL               SKARDU
# 1415     1416      ADVENTURE GHAZI RESORT               SKARDU
#
#                                               ROOM TYPE  \
# 569   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 570   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 571   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 572   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 573   TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# ...                                                 ...
# 1411  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1412  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1413  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1414  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
# 1415  TRIPLE BED FAMILY,DELUX ROOM,HALL,SIDE ROOM,4 ...
#
#                     NEAR FACILITIES    CITY    PARKING  \
# 569   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 570   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 571   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 572   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 573   HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# ...                             ...     ...        ...
# 1411  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1412  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1413  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1414  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
# 1415  HOSPITAL,MARKET,PICNIC POINTS  SKARDU  AVAILABLE
#
#                                                 REVIEWS
# 569   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 570   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 571   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 572   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 573   EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# ...                                                 ...
# 1411  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1412  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1413  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1414  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
# 1415  EXCELLENT STAYED HOTEL,GOOD LOCATION HOTEL, CO...
#
# [234 rows x 8 columns]
# '{"title":{"0":"GILGITI FOOD YARD","1":"COZY LODGE","2":"PAKIZA RESTAURANT","3":"PCG HOTEL","4":"FAIRY MEADOWS INN"},"Correlation":{"0":1.0,"1":0.5625751047,"2":0.5457891314,"3":0.4344592698,"4":0.3907935833},"num of ratings":{"0":295,"1":101,"2":130,"3":106,"4":101}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['ARANDU VALLEY']
normal_place_user_ratings = placemat['BASHO VALLEY']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
#
#
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"BASHO VALLEY","1":"HUSSAIN ABAD WATERFALL","2":"CHUNDA VALLEY","3":"ARANDU VALLEY","4":"MASSHERBRUM BASECAMP"},"Correlation":{"0":1.0,"1":0.3999899956,"2":0.3815233117,"3":0.3695640466,"4":0.3557613797},"num of ratings":{"0":183,"1":255,"2":416,"3":201,"4":339}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df1.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df1.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df1.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df1.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df1.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['KHUNJERAB NATIONAL PARK']
normal_place_user_ratings = placemat['BALTIT FORT']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
#
#
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"BALTIT FORT","1":"SEER","2":"HUNZA HANDICRAFT KARIMABAD","3":"MIACHAR KHOO NAGAR","4":"CHINA YAADGAR DANYORE"},"Correlation":{"0":1.0,"1":0.4328547786,"2":0.426778492,"3":0.4117306577,"4":0.3826814146},"num of ratings":{"0":452,"1":129,"2":220,"3":219,"4":103}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df2.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df2.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df2.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df2.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df2.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['DAR LAY LAKE ASTORE']
normal_place_user_ratings = placemat['FORT KING NATIONAL PARK']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
#
#
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"FORT KING NATIONAL PARK","1":"DAR LAY LAKE ASTORE","2":"BYARSA LAKE","3":"PIONEER SETTLEMENT FOR CREATIVE ART"},"Correlation":{"0":1.0,"1":0.2132629808,"2":0.1375878189,"3":0.0039706765},"num of ratings":{"0":139,"1":184,"2":246,"3":195}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df3.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df3.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df3.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df3.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df3.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['BAGROTE VALLEY']
normal_place_user_ratings = placemat['BILCHAR DUBANI']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
#
#
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"BILCHAR DUBANI","1":"MUZTAGH","2":"BAGROTE VALLEY","3":"LALIK JAAN STADUIM","4":"MARKHOOR CHOWK"},"Correlation":{"0":1.0,"1":0.4207312343,"2":0.3795258056,"3":0.3727004551,"4":0.3559628977},"num of ratings":{"0":140,"1":315,"2":244,"3":261,"4":260}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df4.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df4.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df4.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df4.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df4.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['DASSU GEMSTONE MINES']
normal_place_user_ratings = placemat['FAIRY MEADOWS DIAMER']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
#
#
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
#
#
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"FAIRY MEADOWS DIAMER","1":"MAZINO PASS","2":"DIAMER BASHA DAM","3":"MUZTAGH","4":"DASSU GEMSTONE MINES"},"Correlation":{"0":1.0,"1":0.5897726041,"2":0.5408647812,"3":0.284052426,"4":0.1733318131},"num of ratings":{"0":125,"1":143,"2":207,"3":105,"4":420}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df5.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df5.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df5.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df5.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df5.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['SHIGAR BUDHA ROCK']
normal_place_user_ratings = placemat['SHIGAR BUDHA ROCK']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
#
#
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"SHIGAR BUDHA ROCK","1":"BURGI LA","2":"DAS KHARIM","3":"KINIBARI","4":"HASHUPI GARDEN"},"Correlation":{"0":1.0,"1":0.3291666382,"2":0.2736710976,"3":0.266726419,"4":0.2431836073},"num of ratings":{"0":332,"1":401,"2":280,"3":457,"4":350}}'

# %%
import numpy as np
import pandas as pd
hotels_detail = pd.read_csv("C:\\Users\\Nova Data\\Desktop\Places.csv")
hotels_detail.head()
g =hotels_detail.groupby("CITY")
g
for CITY, data in g:
    print("city:",CITY)
    print("\n")
    print("data:",data)
g.get_group('HUNZA ')
g.get_group('GILGIT')
g.get_group('SKARDU')
g.get_group('ASTORE')
g.get_group('GHIZER')
g.get_group('DIAMER')
g.get_group('SHIGAR')
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data', sep='\t', names=column_names)
df1 = pd.read_csv('u.data', sep='\t', names=column_names)
df2 = pd.read_csv('u.data', sep='\t', names=column_names)
df3 = pd.read_csv('u.data', sep='\t', names=column_names)
df4 = pd.read_csv('u.data', sep='\t', names=column_names)
df5 = pd.read_csv('u.data', sep='\t', names=column_names)
df6 = pd.read_csv('u.data', sep='\t', names=column_names)
df = pd.merge(df,g.get_group('SKARDU'),on='item_id')
df.head()
df1 = pd.merge(df1,g.get_group('HUNZA '),on='item_id')
df1.head()
df2 = pd.merge(df2,g.get_group('ASTORE'),on='item_id')
df2.head()
df3 = pd.merge(df3,g.get_group('GILGIT'),on='item_id')
df3.head()
df4 = pd.merge(df4,g.get_group('DIAMER'),on='item_id')
df4.head()
df5 = pd.merge(df5,g.get_group('SHIGAR'),on='item_id')
df5.head()
df6 = pd.merge(df6,g.get_group('GHIZER'),on='item_id')
df6.head()
import matplotlib.pyplot as plt
import seaborn as sns
df6.groupby('PLACES')['rating'].mean().sort_values(ascending=False).head()
df6.groupby('PLACES')['rating'].count().sort_values(ascending=False).head()
ratings = pd.DataFrame(df6.groupby('PLACES')['rating'].mean())
ratings.head()
ratings['num of ratings'] = pd.DataFrame(df6.groupby('PLACES')['rating'].count())
ratings.head()
ratings.head()
placemat = df6.pivot_table(index='user_id',columns='PLACES',values='rating')
placemat.head()
ratings.sort_values('num of ratings',ascending=False).head(10)
ratings.head()
star_place_user_ratings = placemat['PUNIAL VALLEY']
normal_place_user_ratings = placemat['PUNIAL VALLEY']
star_place_user_ratings.head()
similar_to_starplace = placemat.corrwith(star_place_user_ratings)
similar_to_normalplace = placemat.corrwith(normal_place_user_ratings)
corr_starplace = pd.DataFrame(similar_to_starplace,columns=['Correlation'])
corr_starplace.dropna(inplace=True)
corr_starplace.head()
corr_starplace.sort_values('Correlation',ascending=False).head(10)
corr_starplace = corr_starplace.join(ratings['num of ratings'])
corr_starplace.head()
corr_starplace[corr_starplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
corr_normalplace = pd.DataFrame(similar_to_normalplace,columns=['Correlation'])
corr_normalplace.dropna(inplace=True)
corr_normalplace = corr_normalplace.join(ratings['num of ratings'])
corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head()
xp=(corr_normalplace[corr_normalplace['num of ratings']>100].sort_values('Correlation',ascending=False).head())
xp.reset_index(inplace=True)
z=xp.to_json()
z
# Out:
# city: ASTORE
#
#
# data:      item_id                               PLACES  \
# 229      230                          BYARSA LAKE
# 238      239                  DAR LAY LAKE ASTORE
# 239      240  PIONEER SETTLEMENT FOR CREATIVE ART
# 240      241              FORT KING NATIONAL PARK
# 362      363                          BYARSA LAKE
# 371      372                  DAR LAY LAKE ASTORE
# 372      373  PIONEER SETTLEMENT FOR CREATIVE ART
# 373      374              FORT KING NATIONAL PARK
#
#                                           THINGS TO DO LOCATION    CITY  \
# 229                      SWIMMING,BOATING,PICNIC POINT   ASTORE  ASTORE
# 238                                   SWIMMING,BOATING   ASTORE  ASTORE
# 239  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   ASTORE  ASTORE
# 240                                      NATIONAL PARK   ASTORE  ASTORE
# 362                              BOATING ,PICNIC POINT   ASTORE  ASTORE
# 371                                   SWIMMING,BOATING   ASTORE  ASTORE
# 372                           PICNIC POINT,SEE NATURE    ASTORE  ASTORE
# 373                       LANDSCAPE,DINE AND BONFIRE,    ASTORE  ASTORE
#
#                                         TRACKNG POINTS  \
# 229  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 238  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 239  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 240  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 362  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 371  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 372  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 373  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 229  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 238  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 239  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 240  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 362                                                NaN
# 371                                                NaN
# 372                                                NaN
# 373                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 229  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 238  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 239  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 240  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 362                                                NaN           NaN
# 371                                                NaN           NaN
# 372                                                NaN           NaN
# 373                                                NaN           NaN
# city: ASTORE
#
#
# data:      item_id                  PLACES  \
# 117      118               RAMA LAKE
# 120      121            RAINBOW LAKE
# 140      141            NANGA PARBAT
# 146      147          PHANDER VALLEY
# 147      148  MINIMARG VALLEY ASTORE
# 148      149      RAMA VALLEY ASTORE
# 158      159            RUPAL VALLEY
# 159      160           DERLAY VALLEY
# 250      251               RAMA LAKE
# 253      254            RAINBOW LAKE
# 273      274            NANGA PARBAT
# 280      281  MINIMARG VALLEY ASTORE
# 281      282      RAMA VALLEY ASTORE
# 291      292            RUPAL VALLEY
# 292      293           DERLAY VALLEY
#
#                                           THINGS TO DO LOCATION     CITY  \
# 117                                   SWIMMING,BOATING  ASTORE   ASTORE
# 120                                   SWIMMING,BOATING  ASTORE   ASTORE
# 140                                  CLIMBING,TRACKING  ASTORE   ASTORE
# 146  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   PHANDER  ASTORE
# 147                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 148                       LANDSCAPE , EVENTS, SHOPPING  ASTORE   ASTORE
# 158  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 159  CULTURE, ARCHITECTTURE,INFRASTRUCTURE  , EVENT...  ASTORE   ASTORE
# 250                                   SWIMMING,BOATING  ASTORE   ASTORE
# 253                                   SWIMMING,BOATING  ASTORE   ASTORE
# 273                     CLIMBING,TRACKING,PICNIC POINT  ASTORE   ASTORE
# 280  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...  ASTORE   ASTORE
# 281                         CULTURE , EVENTS, SHOPPING  ASTORE   ASTORE
# 291   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
# 292   ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE , EVENTS  ASTORE   ASTORE
#
#                                         TRACKNG POINTS  \
# 117  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 120  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 140  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 146  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 147  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 148  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 158  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 159  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 250  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 253  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 273  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 280  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 281  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 291  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
# 292  RAINBOW LAKE,MINIMARG VALLEY ASTORE,RAMA,DERLA...
#
#                                                  LAKES  \
# 117  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 120  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 140  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 146  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 147  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 148  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 158  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 159  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 250                                                NaN
# 253                                                NaN
# 273                                                NaN
# 280                                                NaN
# 281                                                NaN
# 291                                                NaN
# 292                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 117  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 120  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 140  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 146  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 147  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 148  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 158  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 159  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 250                                                NaN           NaN
# 253                                                NaN           NaN
# 273                                                NaN           NaN
# 280                                                NaN           NaN
# 281                                                NaN           NaN
# 291                                                NaN           NaN
# 292                                                NaN           NaN
# city: DIAMER
#
#
# data:      item_id                PLACES  \
# 132      133      DIAMER BASHA DAM
# 133      134           DASSU DAME
# 134      135         RAIKOT BRIDGE
# 135      136               MUZTAGH
# 144      145  FAIRY MEADOWS DIAMER
# 173      174  DASSU GEMSTONE MINES
# 265      266      DIAMER BASHA DAM
# 266      267           DASSU DAME
# 267      268         RAIKOT BRIDGE
# 277      278  FAIRY MEADOWS DIAMER
# 331      332           MAZINO PASS
#
#                                          THINGS TO DO LOCATION    CITY  \
# 132                                               DAM   DIAMER  DIAMER
# 133                                          DAM SIDE    DASSU  DIAMER
# 134                                        BRIDGE VEW    DASSU  DIAMER
# 135                                    VALLEY,CULTURE   BASEEN  DIAMER
# 144                               ADVENTURE ,CLIMBING   DIAMER  DIAMER
# 173            CULTURE, ARCHITECTTURE,INFRASTRUCTURE     DASSU  DIAMER
# 265                                         LAKE VIEW   DIAMER  DIAMER
# 266                                         DAM SIDE     DASSU  DIAMER
# 267                                          LAKEVIEW    DASSU  DIAMER
# 277                    CLIMBING,TRACKING,PICNIC POINT   DIAMER  DIAMER
# 331  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   DIAMER  DIAMER
#
#                                         TRACKNG POINTS  \
# 132  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 133  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 134  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 135  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 144  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 173  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 265  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 266  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 267  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 277  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 331  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 132  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 133  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 134  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 135  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 144  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 173  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 277                                                NaN
# 331                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 132  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 133  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 134  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 135  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 144  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 173  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 265                                                NaN           NaN
# 266                                                NaN           NaN
# 267                                                NaN           NaN
# 277                                                NaN           NaN
# 331                                                NaN           NaN
# city: GHIZER
# data:      item_id           PLACES  \
# 149      150  ISHKOMAN VALLEY
# 157      158    PUNIAL VALLEY
# 230      231   BARODAROROKSH
# 290      291    PUNIAL VALLEY
# 363      364   BARODAROROKSH
#
#                                           THINGS TO DO LOCATION    CITY  \
# 149                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 157  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   GHIZER  GHIZER
# 230                                      PICNIC POINT    GHIZER  GHIZER
# 290                 INFRASTRUCTURE ,LANDSCAPE , EVENTS   GHIZER  GHIZER
# 363                      ARCHITECTTURE,INFRASTRUCTURE    GHIZER  GHIZER
#
#                                         TRACKNG POINTS  \
# 149  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 157  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 230  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 290  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 363  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 149  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 157  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 230  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 290                                                NaN
# 363                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 149  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 157  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 230  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 290                                                NaN           NaN
# 363                                                NaN           NaN
# city: GILGIT
#
#
# data:      item_id                    PLACES  \
# 115      116                CHARI KAND
# 116      117            SATRANGI LAKE
# 119      120  INDUS-GILGIT CONFLUENCE
# 121      122             KARGA BUDDAH
# 122      123                SHUL-E-YAL
# ..       ...                       ...
# 376      377                    DAREJA
# 377      378         BAGROTE GRASSLAND
# 378      379             OSHINKHANDASS
# 379      380            DAR VIEW POINT
# 380      381             KHAW TREAKING
#
#                                           THINGS TO DO         LOCATION  \
# 115                             CULTURE, ARCHITECTTURE    NALTER GILGIT
# 116                                   SWIMMING,BOATING    NALTER GILGIT
# 119                   CULTURE, ARCHITECTTURE, SHOPPING    JUGLOT GILGIT
# 121   CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE           GILGIT
# 122               CULTURE,LANDSCAPE , EVENTS, SHOPPING  JUTIYAL  GILGIT
# ..                                                 ...              ...
# 376                                       PICNIC POINT   BAGROTE GILGIT
# 377                           PICNIC POINT,SEE NATURE    BAGROTE GILGIT
# 378           CULTURE, ARCHITECTTURE, EVENTS, SHOPPING           GILGIT
# 379  PICNIC POINT,SEE NATURE , LANDSCAPE,DINE AND B...           GILGIT
# 380           TRACKING,HIKING, SEE NATURE AND WILDLIFE           GILGIT
#
#        CITY                                     TRACKNG POINTS  \
# 115  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 116  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 119  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 121  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 122  GILGIT  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 376  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 377  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 378  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 379  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 380  GILGIT  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 115  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 116  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 119  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 121  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 122  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 376                                                NaN
# 377                                                NaN
# 378                                                NaN
# 379                                                NaN
# 380                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 115  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 116  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 119  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 121  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 122  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 376                                                NaN           NaN
# 377                                                NaN           NaN
# 378                                                NaN           NaN
# 379                                                NaN           NaN
# 380                                                NaN           NaN
#
# [102 rows x 9 columns]
# city: HUNZA
#
#
# data:      item_id             PLACES  \
# 0          1        BALTIT FORT
# 1          2      ULTAR GLACIER
# 2          3       ATTABAD LAKE
# 3          4  KHABASI RESIDENCE
# 4          5   SHISPARE GLACIER
# ..       ...                ...
# 110      111             THENGI
# 111      112            KACHELI
# 112      113              BONAR
# 113      114  MALTAR NILT NAGAR
# 114      115             BARTAR
#
#                                           THINGS TO DO             LOCATION  \
# 0                                 POLO GROUND,HERITAGE     KARIMABAD HUNZA
# 1                                             TRACKING     KARIMABAD HUNZA
# 2                                     SWIMMING,BOATING  SHISKAT GOJAL HUNZA
# 3    CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...          ALTIT HUNZA
# 4                                             TRACKING     HASSANABAD HUNZA
# ..                                                 ...                  ...
# 110                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 111                       LANDSCAPE , EVENTS, SHOPPING    CHALT NAGAR HUNZA
# 112                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 113                         CULTURE , EVENTS, SHOPPING          NAGAR HUNZA
# 114                             CULTURE, ARCHITECTTURE          NAGAR HUNZA
#
#        CITY                                     TRACKNG POINTS  \
# 0    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 1    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 2    HUNZA   ATTABAD LAKE ,DEATH BRIDGE,BORITH LAKE ,PASSU ...
# 3    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# 4    HUNZA   ULTAR PEAK,LADY FINGER,KARIMABAD STREETS,EAGLE...
# ..      ...                                                ...
# 110  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 111  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 112  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 113  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
# 114  HUNZA   GOLDEN PEAK,DIRAN PEAK,RUSH LAKE,TAGAFARI,RAKA...
#
#                                               LAKES  \
# 0    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 1    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 2    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 3    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 4    ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# ..                                              ...
# 110  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 111  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 112  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 113  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
# 114  ATTABAD LAKE,BORITH LAKE,RUSH LAKE,BATURA LAKE
#
#                                               GLACIERS  \
# 0    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 1    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 2    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 3    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 4    ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# ..                                                 ...
# 110  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 111  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 112  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 113  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
# 114  ULTAR GLACIER,HOPPER GLACIER,RAKAPOSHI GLACIER...
#
#                                          CULTURAL FOOD
# 0    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 1    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 2    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 3    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 4    BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# ..                                                 ...
# 110  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 111  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 112  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 113  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
# 114  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...
#
# [115 rows x 9 columns]
# city: SHIGAR
# data:      item_id                     PLACES  \
# 128      129  KHILINGRONG MOSQUE SHIGAR
# 129      130             AMBURIQ MOSQUE
# 164      165             XARBA TSO LAKE
# 174      175        CHOTRON HOT SPRINGS
# 190      191                   BURGI LA
# 192      193          SHIGAR BUDHA ROCK
# 196      197                 DAS KHARIM
# 197      198                   BANAK LA
# 198      199                MAZINO PASS
# 199      200                   KINIBARI
# 203      204             HASHUPI GARDEN
# 225      226            ZHARBA TOS LAKE
# 261      262  KHILINGRONG MOSQUE SHIGAR
# 262      263             AMBURIQ MOSQUE
# 297      298             XARBA TSO LAKE
# 307      308        CHOTRON HOT SPRINGS
# 315      316                     MACHLU
# 323      324                   BURGI LA
# 325      326          SHIGAR BUDHA ROCK
# 329      330                 DAS KHARIM
# 330      331                   BANAK LA
# 332      333                   KINIBARI
# 358      359            ZHARBA TOS LAKE
#
#                                           THINGS TO DO LOCATION    CITY  \
# 128                                            TEMPLE    SHIGAR  SHIGAR
# 129  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 164                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 174  STAY AND DINE,BONFIRE,CAMPING,PICNIC POINT,TRA...   SHIGAR  SHIGAR
# 190         CULTURE , EVENTS, SHOPPING,TRACKING,HIKING   SHIGAR  SHIGAR
# 192           TRACKING,HIKING, SEE NATURE AND WILDLIFE   SHIGAR  SHIGAR
# 196             CULTURE, ARCHITECTTURE,INFRASTRUCTURE    SHIGAR  SHIGAR
# 197                       LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 198       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 199       INFRASTRUCTURE ,LANDSCAPE , EVENTS, SHOPPING   SHIGAR  SHIGAR
# 203                                   CULTURE,SHOPPING   SHIGAR  SHIGAR
# 225                                            BOATING   SHIGAR  SHIGAR
# 261                                            TEMPLE    SHIGAR  SHIGAR
# 262                                            TEMPLE    SHIGAR  SHIGAR
# 297                                   SWIMMING,BOATING   SHIGAR  SHIGAR
# 307   CULTURE, ARCHITECTTURE,INFRASTRUCTURE , SHOPPING   SHIGAR  SHIGAR
# 315                               HIKING,STAY AND DINE   SHIGAR  SHIGAR
# 323                             TRACKING,PICNIC POINT,   SHIGAR  SHIGAR
# 325                       HIKING,TRACKING,PICNIC POINT   SHIGAR  SHIGAR
# 329                TRACKING,PICNIC POINT,STAY AND DINE   SHIGAR  SHIGAR
# 330  CULTURE, ARCHITECTTURE,INFRASTRUCTURE ,LANDSCA...   SHIGAR  SHIGAR
# 332            ARCHITECTTURE,INFRASTRUCTURE ,LANDSCAPE   SHIGAR  SHIGAR
# 358                                           SWIMMING   SHIGAR  SHIGAR
#
#                                         TRACKNG POINTS  \
# 128  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 129  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 164  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 174  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 190  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 192  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 196  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 197  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 198  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 199  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 203  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 225  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 261  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 262  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 297  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 307  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 315  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 323  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 325  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 329  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 330  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 332  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 358  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 128  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 129  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 164  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 174  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 190  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 192  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 196  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 197  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 198  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 199  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 203  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 225  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 261                                                NaN
# 262                                                NaN
# 297                                                NaN
# 307                                                NaN
# 315                                                NaN
# 323                                                NaN
# 325                                                NaN
# 329                                                NaN
# 330                                                NaN
# 332                                                NaN
# 358                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 128  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 129  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 164  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 174  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 190  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 192  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 196  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 197  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 198  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 199  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 203  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 225  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 261                                                NaN           NaN
# 262                                                NaN           NaN
# 297                                                NaN           NaN
# 307                                                NaN           NaN
# 315                                                NaN           NaN
# 323                                                NaN           NaN
# 325                                                NaN           NaN
# 329                                                NaN           NaN
# 330                                                NaN           NaN
# 332                                                NaN           NaN
# 358                                                NaN           NaN
# city: SKARDU
#
#
# data:      item_id                        PLACES  \
# 118      119               CHAQCHAN MOSQUE
# 123      124           MANTHAL BUDDHA ROCK
# 124      125                KHARPOCHO FORT
# 127      128  ASTANA OF SYED MIR MUHAMMAD
# 130      131                    K-2 SKARDU
# ..       ...                           ...
# 364      365                 GHORASHI LAKE
# 365      366                      K2 MUSEM
# 366      367                   SKARDU FORT
# 367      368                 DEOSAI PLANES
# 368      369              SHINGRILA RESORT
#
#                                          THINGS TO DO         LOCATION  \
# 118                  CULTURE, ARCHITECTTURE, SHOPPING  KHAPULU SKARDU
# 123              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 124              CULTURE,LANDSCAPE , EVENTS, SHOPPING           SKARDU
# 127                                           TEMPLE   KHAPULU SKARDU
# 130                                          CLIMBING        K2 SKARDU
# ..                                                ...              ...
# 364                                  SWIMMING,BOATING         KHARMANG
# 365  ARCHITECTTURE,INFRASTRUCTURE ,HISTORICAL THINGS,           SKARDU
# 366                        CULTURE,  EVENTS, SHOPPING           SKARDU
# 367                           PICNIC POINT,SEE NATURE           SKARDU
# 368          PICNIC POINT, LANDSCAPE,DINE AND BONFIRE           SKARDU
#
#        CITY                                     TRACKNG POINTS  \
# 118  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# 123  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 124  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 127  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 130  SKARDU  INDUS-GILGIT CONFLUENCE ,BROAD PEAK,KUTWAL LAK...
# ..      ...                                                ...
# 364  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 365  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 366  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 367  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
# 368  SKARDU  MANTHAL BUDDHA ROCK,KHARPOCHO FORT,AMBURIQ MOS...
#
#                                                  LAKES  \
# 118  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 123  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 124  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 127  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# 130  SATRANGI LAKE ,SATRANGI LAKE,RAMA LAKE,RUSH LA...
# ..                                                 ...
# 364                                                NaN
# 365                                                NaN
# 366                                                NaN
# 367                                                NaN
# 368                                                NaN
#
#                                               GLACIERS CULTURAL FOOD
# 118  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 123  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 124  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 127  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# 130  BUROS-SHAPIK,GIYALIN,CHAMURKII,MOLIDA,SHARBAT,...           NaN
# ..                                                 ...           ...
# 364                                                NaN           NaN
# 365                                                NaN           NaN
# 366                                                NaN           NaN
# 367                                                NaN           NaN
# 368                                                NaN           NaN
#
# [84 rows x 9 columns]
# '{"PLACES":{"0":"PUNIAL VALLEY","1":"BARODAROROKSH ","2":"ISHKOMAN VALLEY"},"Correlation":{"0":1.0,"1":0.1525833361,"2":0.0102488904},"num of ratings":{"0":187,"1":179,"2":157}}'
